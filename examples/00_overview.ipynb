# %% [markdown]
# ---
# title: Overview
# ---

# %% [markdown]
# Cellestial is an interactive single-cell plotting library.

# %%
import cellestial as cl
import scanpy as sc
from lets_plot import *

LetsPlot.setup_html()

data = sc.read("data/pbmc3k_pped.h5ad")

# %% [markdown]
# ## Tooltips

# %% [markdown]
# By default, cellestial produces HTML plots with `geoms` reveal tooltips when hovering.

# %%
plot = cl.dimensional(
    data, dimensions="umap", key="leiden", size=0.6, axis_type="arrow", arrow_length=0.5
)
plot

# %% [markdown]
# `dimensional` plot produces dimensionalilty reduction plots by taking `dimensions` argument. Yet, the subset of plots `pca`, `umap` and `tsne` are also available.

# %% [markdown]
# Also, the `expression` plot is also a subset of `dimensional` plot but it only works with __genes__.

# %% [markdown]
# ## Zooming and Paning

# %% [markdown]
# There are also zoomable and panable if specified.

# %%
plot = cl.dimensional(
    data,
    dimensions="umap",
    key="leiden",
    size=0.6,
    interactive=True,
    axis_type="arrow",
)
plot

# %% [markdown]
# Note that this functionality can be added via `+ ggtb()` layer of __lets_plot__.

# %% [markdown]
# ## High Customizability

# %% [markdown]
# Cellestial uses __Lets-Plot__, a __ggplot2__ impelementation in Pyton. As such, it allows adding or changing layers. Including color palettes, titles, labels, size etc., .

# %% [markdown]
# Here an example with switching color palette to `hue` which is also the __ggplot2__ and __Seurat__ defaults. Also, other `theme()` based customizations are given as examples.

# %%
gggrid(
    [
        plot + scale_color_hue() + labs(title="Change color palette"),
        plot
        + theme(legend_text=element_text(size=15))
        + labs(title="Change legend text size"),
        plot
        + theme(axis_title=element_blank())
        + labs(title="Remove axis titles"),
    ],
    ncol=2,
) + ggsize(1000, 800)

# %% [markdown]
# Indeed, you can modify the size.

# %%
plot += ggsize(500, 400)
plot

# %% [markdown]
# ## Multi-Plots

# %% [markdown]
# Multi-plots uses `dimensional` plot and grids list of keys given.

# %% [markdown]
# While single-plot functions which generate a single-plot object, Multi-plot functions have __plural__ names which provides predictable behaviors.

# %% [markdown]
# So, `pca` becomes `pcas`, `umap` becomes `umaps`, `tsne` becomes `tsnes` etc., for multi-plots.

# %%
umap_grid = (
    cl.umaps(
        data,
        keys=["leiden", "HBD", "NEAT1", "IGKC"],
        ncol=2,
        size=0.6,
        color_high="#D2042D",  # works with hex codes, rgb codes, and names (red, blue, etc.)
    )
    + ggsize(900, 700)
)
umap_grid

# %%
type(umap_grid)

# %%
vars(umap_grid).get('_SupPlotsSpec__figures')[(0,1,2)]

# %%
gggrid(vars(umap_grid).get('_SupPlotsSpec__figures')[0:2])

# %%
vars(plot)

# %%
vars(plot).keys()

# %%
vars(plot).get('_FeatureSpec__props').keys()

# %%
vars(plot).get('_FeatureSpec__props').get('data')

# %%
cl.versions()
