# %% [markdown]
# ---
# title: elbow
# ---

# %%
import cellestial as cl
import scanpy as sc
from lets_plot import *

LetsPlot.setup_html()

data = sc.read("data/pbmc3k_mini.h5ad")

# %% [markdown]
# ## A simple elbow plot
