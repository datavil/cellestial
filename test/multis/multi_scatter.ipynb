# %%
import cellestial as cl
import scanpy as sc
from lets_plot import *

LetsPlot.setup_html()

data = sc.read("data/pbmc3k_pped.h5ad")

# %%
data.obs

# %%
cl.scatters(
    data,
    x="n_genes_by_counts",
    y="total_counts",
    color="sample",
    layers=scale_color_hue()
)

# %%
cl.scatters(
    data,
    x="n_genes_by_counts",
    y=["total_counts","pct_counts_mt"],
    color="sample",
    layers=scale_color_hue()
)

# %%
cl.scatters(
    data,
    x=["n_genes_by_counts","pct_counts_in_top_100_genes"],
    y=["total_counts","pct_counts_mt"],
    color="sample",
    layers=scale_color_hue()
)

# %%
cl.scatters(
    data,
    x=["n_genes_by_counts","pct_counts_in_top_100_genes"],
    y=["total_counts","pct_counts_mt"],
    color="sample",
    layers=[scale_color_hue() , theme(legend_position="top")]
)

# %%
cl.versions()
