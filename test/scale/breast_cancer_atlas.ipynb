# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

LetsPlot.setup_html(no_js=True)

# %%
data = sc.read_h5ad("data/breast_cancer_atlas.h5ad")

# %%
sc.pp.sample(data, 0.2)

# %%
umap = cl.umap(data, "cell_type", axis_type="arrow") + ggsize(1200, 800)
# umap

# %%
umap

# %%
umap.to_png("assets/breast_cancer_atlas_umap.png")
