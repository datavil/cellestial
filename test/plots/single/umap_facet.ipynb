# %%
import cellestial as cl
import scanpy as sc
from lets_plot import *

LetsPlot.setup_html()

data = sc.read("data/pbmc3k_pped.h5ad")
# Out:
#         <div id="0522e6"></div>
#         <script type="text/javascript" data-lets-plot-script="library">
#             if(!window.letsPlotCallQueue) {
#                 window.letsPlotCallQueue = [];
#             };
#             window.letsPlotCall = function(f) {
#                 window.letsPlotCallQueue.push(f);
#             };
#             (function() {
#                 var script = document.createElement("script");
#                 script.type = "text/javascript";
#                 script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js";
#                 script.onload = function() {
#                     window.letsPlotCall = function(f) {f();};
#                     window.letsPlotCallQueue.forEach(function(f) {f();});
#                     window.letsPlotCallQueue = [];
#
#                 };
#                 script.onerror = function(event) {
#                     window.letsPlotCall = function(f) {};    // noop
# ...

# %%
data.obs
# Out:
#                    sample  n_genes_by_counts  log1p_n_genes_by_counts  \
# AAACCCAAGGATGGCT-1   s1d1               2103                 7.651596
# AAACCCAAGGCCTAGA-1   s1d1               3916                 8.273081
# AAACCCAAGTGAGTGC-1   s1d1                683                 6.527958
# AAACCCACAAGAGGCT-1   s1d1               4330                 8.373554
# AAACCCACATCGTGGC-1   s1d1                325                 5.786897
# ...                   ...                ...                      ...
# TTTGTTGAGAGTCTGG-1   s1d3                277                 5.627621
# TTTGTTGCAGACAATA-1   s1d3               3797                 8.242230
# TTTGTTGCATGTTACG-1   s1d3               3089                 8.035926
# TTTGTTGGTAGTCACT-1   s1d3                379                 5.940171
# TTTGTTGTCGCGCTGA-1   s1d3               1599                 7.377759
#
#                     total_counts  log1p_total_counts  \
# AAACCCAAGGATGGCT-1        8663.0            9.066932
# ...

# %%
dim = cl.dimensional(
    data,
    dimensions="umap",
    key="leiden",
    size=1,
    axis_type=None,
    add_tooltips=["n_genes", "total_counts_hb", "MT-ND2"],
    legend_ondata=True,
    ondata_size=12,
    ondata_color="black",
    ondata_fontface="bold",
    ondata_family="sans",
    ondata_alpha=0.8,
)
dim + ggsize(800, 600)
# Out:
#    <div id="J1HD2B" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("J1HD2B");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...

# %%
(
    dim
    + facet_wrap(facets=["sample"])
    + ggsize(600, 900)
)
# Out:
#    <div id="42JgKy" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("42JgKy");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# ...

# %%
cl.retrieve(dim)
# Out:
# shape: (16_680, 27)
# ┌────────────┬────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Barcode    ┆ sample ┆ n_genes_by ┆ log1p_n_g ┆ … ┆ X_TSNE1   ┆ X_TSNE2   ┆ X_UMAP1   ┆ X_UMAP2   │
# │ ---        ┆ ---    ┆ _counts    ┆ enes_by_c ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ cat    ┆ ---        ┆ ounts     ┆   ┆ f32       ┆ f32       ┆ f32       ┆ f32       │
# │            ┆        ┆ i32        ┆ ---       ┆   ┆           ┆           ┆           ┆           │
# │            ┆        ┆            ┆ f64       ┆   ┆           ┆           ┆           ┆           │
# ╞════════════╪════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ AAACCCAAGG ┆ s1d1   ┆ 2103       ┆ 7.651596  ┆ … ┆ -8.471021 ┆ 0.673473  ┆ 10.702534 ┆ 1.695078  │
# │ ATGGCT-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# ...
