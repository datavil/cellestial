# %%
import cellestial as cl
import scanpy as sc

from lets_plot import *

data = sc.read("data/pbmc3k_mini.h5ad")

# %%
data.var_names

# %%
cl.umaps(data, keys=["leiden", "PRKY", "MTCP1", "PLCH2"], ncol=2, sharex=True)
