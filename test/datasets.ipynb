# %%
import cellestial as cl

# %%
data = cl.datasets.pbmc3k(cache_directory="data")

# %%
plot = cl.heatmap(
    data,
    keys=["n_cells_by_counts", "mean_counts"],
    group_by="highly_variable",
    axis=1,
    aggregate=True,
    group_lines_size=0.00
)
plot

# %%
data.var

# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

data = cl.datasets.pbmc3k(cache_directory="data")

markers = ["C1QA", "PSAP", "CD79A", "CD79B", "CST3", "LYZ"]

cl.heatmap(
    data,
    group_by="cell_type_lvl1",
    keys=markers,
    dendrogram=True,
) + scale_fill_viridis()

# %%
cl.heatmap(
    data,
    group_by="cell_type_lvl1",
    keys=markers,
    geom="raster",
    group_lines_size=0.5,
    group_lines_color="white",
    dendrogram=True,
    dendrogram_size=1,
    group_bars_labels=True,
    group_bars=True,
) + scale_fill_viridis()
