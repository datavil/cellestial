# %%
import cellestial as cl

# %%
import mudata as md

mdata = md.read_h5mu("data/minipbcite.h5mu")

# %%
mdata.var_names

# %%
cl.dimensional(mdata, size=5, key="leiden")

# %%
cl.violin(mdata,key="rna:IRF8", fill="leiden")
