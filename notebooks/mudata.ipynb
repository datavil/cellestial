# %%
! curl -L -o data/minipbcite.h5mu  https://github.com/gtca/h5xx-datasets/raw/main/datasets/minipbcite.h5mu

# %%
from mudata import MuData
import mudata as md
import cellestial as cl

mdata = md.read_h5mu("data/minipbcite.h5mu")

# %%
mdata

# %%
mdata.var_names

# %%
mdata.var.loc["rna:IL2RA"]

# %%
dir(mdata)

# %%
mdata.obs

# %%
mdata["rna"].X

# %%
mdata.X

# %%
mdata["prot"].var_names

# %%
mdata["rna"].var_names

# %%
mdata

# %%
mdata.to_anndata().var_names

# %%
cl.dimensional(
    mdata,
    use_key="X_wnn_umap",
    key="rna:NKG7",
)
