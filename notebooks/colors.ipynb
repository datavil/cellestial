# %%
from lets_plot import *

LetsPlot.setup_html()

# Hand-picked colors for cellestial
TEAL = "#219B9D"
RED = "#D2042D"
CHERRY = "#AF1740"
BLUE = "#377EB8"
LIGHT_GRAY = "#E6E6E6"
# Out:
#             <div id="M6CnHW"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("M6CnHW").appendChild(div);
#                     };
#                     var e = document.getElementById("M6CnHW");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
def show_colors():
    colors = {"TEAL": TEAL, "RED": RED, "CHERRY": CHERRY, "BLUE": BLUE, "LIGHT_GRAY": LIGHT_GRAY}

    plots = []
    for color in colors:
        text_color = "white" if color != "LIGHT_GRAY" else "black"

        plot = (
            ggplot({"x": [1], "y": [1]})
            + geom_point(aes(x="x", y="y"), fill=colors[color], shape=22, size=90, color="#1f1f1f")
            + geom_text(
                aes(x="x", y="y"),
                label=f"{color}\n",
                color=text_color,
                size=14,
                fontface="bold",
                family="Arial",
            )
            + geom_text(
                aes(x="x", y="y"),
                label=f"\n{colors[color]}",
                color=text_color,
                size=10,
                fontface="regular",
                family="sans-serif",
            )
            + theme_void()
        )
        plots.append(plot)

    ncol = 3
    nrow = len(colors) // ncol
    if len(colors) % ncol != 0:
        nrow += 1

    return gggrid(plots, ncol=3, hspace=0, vspace=0) + ggsize(ncol * 200, nrow * 200)


show_colors()
# Out:
#    <div id="TR27No"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("TR27No");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "ggsize":{
# "width":600.0,
# "height":400.0
# },
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":2.0,
# "hspace":0.0,
# "vspace":0.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#219B9D",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"TEAL\n",
# "color":"white",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#219B9D",
# "color":"white",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"11"
# },{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#D2042D",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"RED\n",
# "color":"white",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#D2042D",
# "color":"white",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"12"
# },{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#AF1740",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"CHERRY\n",
# "color":"white",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#AF1740",
# "color":"white",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"13"
# },{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#377EB8",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"BLUE\n",
# "color":"white",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#377EB8",
# "color":"white",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"14"
# },{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#E6E6E6",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"LIGHT_GRAY\n",
# "color":"black",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#E6E6E6",
# "color":"black",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"15"
# },"blank"]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>

# %%
import cellestial as cl
# Out:
#             <div id="bKWIjZ"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("bKWIjZ").appendChild(div);
#                     };
#                     var e = document.getElementById("bKWIjZ");
#                     e.appendChild(script);
#                 })()
#             </script>
#             <div id="4M6Mcx"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("4M6Mcx").appendChild(div);
#                     };
#                     var e = document.getElementById("4M6Mcx");
#                     e.appendChild(script);
#                 })()
#             </script>
#             <div id="XD45sT"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.2/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("XD45sT").appendChild(div);
#                     };
#                     var e = document.getElementById("XD45sT");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
cl.show_colors()
# Out:
#    <div id="Og70cv"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    var containerDiv = document.getElementById("Og70cv");
#    var observer = new ResizeObserver(function(entries) {
#        for (let entry of entries) {
#            var width = containerDiv.clientWidth
#            if (entry.contentBoxSize && width > 0) {
#
#                // Render plot
#                if (observer) {
#                    observer.disconnect();
#                    observer = null;
#                }
#
#                var plotSpec={
# "ggsize":{
# "width":600.0,
# "height":400.0
# },
# "kind":"subplots",
# "layout":{
# "ncol":3.0,
# "nrow":2.0,
# "hspace":0.0,
# "vspace":0.0,
# "name":"grid"
# },
# "figures":[{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#219B9D",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"TEAL\n",
# "color":"white",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#219B9D",
# "color":"white",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"1"
# },{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#D2042D",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"RED\n",
# "color":"white",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#D2042D",
# "color":"white",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"2"
# },{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#AF1740",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"CHERRY\n",
# "color":"white",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#AF1740",
# "color":"white",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"3"
# },{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#377EB8",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"BLUE\n",
# "color":"white",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#377EB8",
# "color":"white",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"4"
# },{
# "data":{
# "x":[1.0],
# "y":[1.0]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"x"
# },{
# "type":"int",
# "column":"y"
# }]
# },
# "theme":{
# "name":"classic",
# "line":"blank",
# "axis":"blank"
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "fill":"#E6E6E6",
# "shape":22.0,
# "size":90.0,
# "color":"#1f1f1f",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"LIGHT_GRAY\n",
# "color":"black",
# "size":14.0,
# "fontface":"bold",
# "family":"Arial",
# "data":{
# }
# },{
# "geom":"text",
# "mapping":{
# "x":"x",
# "y":"y"
# },
# "data_meta":{
# },
# "label":"\n#E6E6E6",
# "color":"black",
# "size":10.0,
# "fontface":"regular",
# "family":"sans-serif",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"5"
# },"blank"]
# };
#                window.letsPlotCall(function() {
#
#                var toolbar = null;
#                var plotContainer = containerDiv;
#
#                    var options = {
#                        sizing: {
#                            width_mode: "min",
#                            height_mode: "scaled",
#                            width: width
#                        }
#                    };
#                    var fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, -1, -1, plotContainer, options);
#                    if (toolbar) {
#                      toolbar.bind(fig);
#                    }
#                });
#
#                break;
#            }
#        }
#    });
#
#    observer.observe(containerDiv);
#
#    // ----------
#    })();
#
#    </script>
