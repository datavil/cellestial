# %%
from __future__ import annotations

from collections.abc import Iterable, Sequence
from typing import Any

import polars as pl
from anndata import AnnData
from lets_plot import (
    LetsPlot,
    aes,
    element_blank,
    element_rect,
    element_text,
    geom_point,
    ggplot,
    ggsize,
    ggtb,
    guide_legend,
    guides,
    layer_tooltips,
    scale_color_gradient,
    scale_fill_gradient,
    scale_size,
    scale_x_discrete,
    scale_y_discrete,
    theme,
    theme_classic,
)
from lets_plot.plot.core import PlotSpec

from cellestial import retrieve
from cellestial.frames import build_frame
from cellestial.util import _decide_tooltips, _range_inclusive
from cellestial.themes import _THEME_DOTPLOT

# %%
import anndata

data = anndata.read_h5ad("data/pbmc3k_pped.h5ad")

# %%
hvg = data.var_names[data.var["highly_variable"]].tolist()[:30]

# %%
frame = build_frame(data=data, axis=0, variable_keys=hvg)

# %%
frame
# Out:
# shape: (16_680, 51)
# ┌────────────┬────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ barcode    ┆ sample ┆ n_genes_by ┆ log1p_n_g ┆ … ┆ AL031432. ┆ STMN1     ┆ CNKSR1    ┆ ZNF683    │
# │ ---        ┆ ---    ┆ _counts    ┆ enes_by_c ┆   ┆ 1         ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ cat    ┆ ---        ┆ ounts     ┆   ┆ ---       ┆ f32       ┆ f32       ┆ f32       │
# │            ┆        ┆ i32        ┆ ---       ┆   ┆ f32       ┆           ┆           ┆           │
# │            ┆        ┆            ┆ f64       ┆   ┆           ┆           ┆           ┆           │
# ╞════════════╪════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ AAACCCAAGG ┆ s1d1   ┆ 2103       ┆ 7.651596  ┆ … ┆ -0.022962 ┆ -0.464612 ┆ -0.047801 ┆ -0.107066 │
# │ ATGGCT-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ AAACCCAAGG ┆ s1d1   ┆ 3916       ┆ 8.273081  ┆ … ┆ -0.022962 ┆ -0.464612 ┆ -0.047801 ┆ -0.107066 │
# │ CCTAGA-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ AAACCCAAGT ┆ s1d1   ┆ 683        ┆ 6.527958  ┆ … ┆ -0.022962 ┆ -0.464612 ┆ -0.047801 ┆ -0.107066 │
# │ GAGTGC-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ AAACCCACAA ┆ s1d1   ┆ 4330       ┆ 8.373554  ┆ … ┆ -0.022962 ┆ 2.409269  ┆ -0.047801 ┆ -0.107066 │
# │ GAGGCT-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ AAACCCACAT ┆ s1d1   ┆ 325        ┆ 5.786897  ┆ … ┆ -0.022962 ┆ -0.464612 ┆ -0.047801 ┆ -0.107066 │
# │ CGTGGC-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ …          ┆ …      ┆ …          ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ TTTGTTGAGA ┆ s1d3   ┆ 277        ┆ 5.627621  ┆ … ┆ -0.022962 ┆ -0.464612 ┆ -0.047801 ┆ -0.107066 │
# │ GTCTGG-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ TTTGTTGCAG ┆ s1d3   ┆ 3797       ┆ 8.24223   ┆ … ┆ -0.022962 ┆ 1.316255  ┆ -0.047801 ┆ -0.107066 │
# │ ACAATA-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ TTTGTTGCAT ┆ s1d3   ┆ 3089       ┆ 8.035926  ┆ … ┆ -0.022962 ┆ 0.004867  ┆ -0.047801 ┆ -0.107066 │
# │ GTTACG-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ TTTGTTGGTA ┆ s1d3   ┆ 379        ┆ 5.940171  ┆ … ┆ -0.022962 ┆ -0.464612 ┆ -0.047801 ┆ -0.107066 │
# │ GTCACT-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# │ TTTGTTGTCG ┆ s1d3   ┆ 1599       ┆ 7.377759  ┆ … ┆ -0.022962 ┆ -0.464612 ┆ -0.047801 ┆ -0.107066 │
# │ CGCTGA-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# └────────────┴────────┴────────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
index = [x for x in frame.columns if x not in hvg]

# %%
long_frame = frame.unpivot(on=hvg, index=index, variable_name="gene", value_name="expression")

# %%
long_frame
# Out:
# shape: (500_400, 23)
# ┌─────────────┬────────┬─────────────┬────────────┬───┬─────────┬────────┬────────────┬────────────┐
# │ barcode     ┆ sample ┆ n_genes_by_ ┆ log1p_n_ge ┆ … ┆ n_genes ┆ leiden ┆ gene       ┆ expression │
# │ ---         ┆ ---    ┆ counts      ┆ nes_by_cou ┆   ┆ ---     ┆ ---    ┆ ---        ┆ ---        │
# │ str         ┆ cat    ┆ ---         ┆ nts        ┆   ┆ i64     ┆ cat    ┆ str        ┆ f32        │
# │             ┆        ┆ i32         ┆ ---        ┆   ┆         ┆        ┆            ┆            │
# │             ┆        ┆             ┆ f64        ┆   ┆         ┆        ┆            ┆            │
# ╞═════════════╪════════╪═════════════╪════════════╪═══╪═════════╪════════╪════════════╪════════════╡
# │ AAACCCAAGGA ┆ s1d1   ┆ 2103        ┆ 7.651596   ┆ … ┆ 2103    ┆ 0      ┆ AL390719.2 ┆ -0.015695  │
# │ TGGCT-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# │ AAACCCAAGGC ┆ s1d1   ┆ 3916        ┆ 8.273081   ┆ … ┆ 3916    ┆ 10     ┆ AL390719.2 ┆ -0.015695  │
# │ CTAGA-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# │ AAACCCAAGTG ┆ s1d1   ┆ 683         ┆ 6.527958   ┆ … ┆ 683     ┆ 15     ┆ AL390719.2 ┆ -0.015695  │
# │ AGTGC-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# │ AAACCCACAAG ┆ s1d1   ┆ 4330        ┆ 8.373554   ┆ … ┆ 4330    ┆ 17     ┆ AL390719.2 ┆ -0.015695  │
# │ AGGCT-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# │ AAACCCACATC ┆ s1d1   ┆ 325         ┆ 5.786897   ┆ … ┆ 325     ┆ 6      ┆ AL390719.2 ┆ -0.015695  │
# │ GTGGC-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# │ …           ┆ …      ┆ …           ┆ …          ┆ … ┆ …       ┆ …      ┆ …          ┆ …          │
# │ TTTGTTGAGAG ┆ s1d3   ┆ 277         ┆ 5.627621   ┆ … ┆ 277     ┆ 6      ┆ ZNF683     ┆ -0.107066  │
# │ TCTGG-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# │ TTTGTTGCAGA ┆ s1d3   ┆ 3797        ┆ 8.24223    ┆ … ┆ 3797    ┆ 16     ┆ ZNF683     ┆ -0.107066  │
# │ CAATA-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# │ TTTGTTGCATG ┆ s1d3   ┆ 3089        ┆ 8.035926   ┆ … ┆ 3089    ┆ 5      ┆ ZNF683     ┆ -0.107066  │
# │ TTACG-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# │ TTTGTTGGTAG ┆ s1d3   ┆ 379         ┆ 5.940171   ┆ … ┆ 379     ┆ 1      ┆ ZNF683     ┆ -0.107066  │
# │ TCACT-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# │ TTTGTTGTCGC ┆ s1d3   ┆ 1599        ┆ 7.377759   ┆ … ┆ 1599    ┆ 0      ┆ ZNF683     ┆ -0.107066  │
# │ GCTGA-1     ┆        ┆             ┆            ┆   ┆         ┆        ┆            ┆            │
# └─────────────┴────────┴─────────────┴────────────┴───┴─────────┴────────┴────────────┴────────────┘

# %%
stats_frame = long_frame.group_by(["leiden", "gene"]).agg(
    [
        pl.col("expression").mean().alias("avg_exp"),
        (pl.col("expression") > 1).mean().mul(100).alias("pct_exp"),
    ]
)

# %%
stats_frame
# Out:
# shape: (600, 4)
# ┌────────┬────────────┬───────────┬──────────┐
# │ leiden ┆ gene       ┆ avg_exp   ┆ pct_exp  │
# │ ---    ┆ ---        ┆ ---       ┆ ---      │
# │ cat    ┆ str        ┆ f32       ┆ f64      │
# ╞════════╪════════════╪═══════════╪══════════╡
# │ 7      ┆ AL031432.1 ┆ -0.022962 ┆ 0.0      │
# │ 10     ┆ LINC01355  ┆ 0.165865  ┆ 5.206074 │
# │ 18     ┆ LINC01355  ┆ 0.035581  ┆ 2.941176 │
# │ 14     ┆ NBPF3      ┆ 0.071943  ┆ 1.856764 │
# │ 19     ┆ C1QA       ┆ -0.048821 ┆ 0.0      │
# │ …      ┆ …          ┆ …         ┆ …        │
# │ 2      ┆ AL513320.1 ┆ -0.028972 ┆ 0.0      │
# │ 14     ┆ AL031727.2 ┆ -0.012204 ┆ 0.0      │
# │ 5      ┆ CHD5       ┆ -0.019927 ┆ 0.0      │
# │ 2      ┆ LINC01783  ┆ -0.018487 ┆ 0.0      │
# │ 11     ┆ AL031432.1 ┆ -0.022962 ┆ 0.0      │
# └────────┴────────────┴───────────┴──────────┘

# %%
from lets_plot import *

LetsPlot.setup_html()
# Out:
#         <div id="HHsQJj"></div>
#         <script type="text/javascript" data-lets-plot-script="library">
#             if(!window.letsPlotCallQueue) {
#                 window.letsPlotCallQueue = [];
#             };
#             window.letsPlotCall = function(f) {
#                 window.letsPlotCallQueue.push(f);
#             };
#             (function() {
#                 var script = document.createElement("script");
#                 script.type = "text/javascript";
#                 script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js";
#                 script.onload = function() {
#                     window.letsPlotCall = function(f) {f();};
#                     window.letsPlotCallQueue.forEach(function(f) {f();});
#                     window.letsPlotCallQueue = [];
#
#                 };
#                 script.onerror = function(event) {
#                     window.letsPlotCall = function(f) {};    // noop
#                     window.letsPlotCallQueue = [];
#                     var div = document.createElement("div");
#                     div.style.color = 'darkred';
#                     div.textContent = 'Error loading Lets-Plot JS';
#                     document.getElementById("HHsQJj").appendChild(div);
#                 };
#                 var e = document.getElementById("HHsQJj");
#                 e.appendChild(script);
#             })()
#         </script>

# %%
(
    ggplot(stats_frame, aes(x="gene", y="leiden"))
    + geom_point(aes(size="pct_exp", color="avg_exp"))
    +
    # Styling to match the Scanpy aesthetic
    scale_color_gradient(low="lightgrey", high="blue")
    + scale_size(range=[2, 5])
    + theme_minimal2()
    + scale_y_discrete(expand=[0.05, 0.05])
    + scale_x_discrete(expand=[0.025, 0.025])
)
# Out:
#    <div id="Uc0giU" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("Uc0giU");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
#
1","AL162741.1","UBR4","LINC01783","AL021155.5","PLCH2","AL031005.2","C1QA","TMEM52","WNT4","TMEM52","C1QC","AL031005.2","AL589739.1","AL031432.1","VPS13D","LINC01355","AL031432.1","AL031432.1","FAM131C","CHD5","AL031432.1","NBPF3","STMN1","AL513320.1","ZNF683","AL513320.1","LINC01772","AL390719.2","C1QA","VPS13D","C1QC","AL031005.2","LINC01786","LINC01783","CNKSR1","LINC01786","LINC01355","AL513320.1","AL031432.1","ID3","AL391244.2","C1QTNF12","AL513320.1","FAM131C","C1QB","FAM131C","C1QTNF12","LINC01786","C1QC","C1QA","AL031432.1","LINC01786","PLCH2","ZNF683","UBR4","AL589739.1","C1QA","ZNF683","NBPF3","LINC01772","ID3","AL513320.1","ZNF683","LINC01783","AL589739.1","FAM131C","C1QA","AL513320.1","C1QB","ZNF683","STMN1","CHD5","AL391244.2","WNT4","LINC01786","AL031283.1","TMEM52","STMN1","FAM131C","AL031283.1","UBR4","C1QC","ID3","AL021155.5","AL031432.1","FAM131C","STMN1","AL031283.1","AL513320.1","ID3","ZNF683","LINC01772","AL162741.1","C1QC","C1QTNF12","AL390719.2","LINC01783","C1QB","NBPF3","LINC01772","TMEM52","NBPF3","LINC01772","AL031005.2","UBR4","UBR4","LINC01355","C1QA","ID3","LINC01783","AL390719.2","VPS13D","C1QTNF12","LINC01786","VPS13D","STMN1","VPS13D","LINC01772","UBR4","ID3","C1QA","AL513320.1","AL031727.2","AL391244.2","FAM131C","AL031727.2","AL031283.1","STMN1","AL031005.2","ID3","CNKSR1","AL589739.1","AL513320.1","AL031005.2","C1QB","ZNF683","CNKSR1","AL589739.1","PLCH2","ZNF683","C1QA","C1QC","LINC01786","ID3","C1QB","AL162741.1","LINC01772","LINC01355","C1QB","FAM131C","LINC01772","WNT4","LINC01772","PLCH2","CNKSR1","LINC01783","AL391244.2","LINC01786","LINC01783","UBR4","TMEM5 ...

# %%
def dotplot(
    data: AnnData,
    keys: Sequence[str],
    group_by: str,
    *,
    threshold: float = 0,
    color_low: str = "#e6e6e6",
    color_high: str = "#D2042D",
    show_tooltips: bool = True,
    interactive: bool = False,
    **geom_kwargs: dict[str, Any],
) -> PlotSpec:
    frame = build_frame(data=data, axis=0, variable_keys=keys)
    index_columns = [x for x in frame.columns if x not in keys]
    long_frame = frame.unpivot(
        on=keys,
        index=index_columns,
        variable_name="gene",
        value_name="expression",
    )
    stats_frame = long_frame.group_by([group_by, "gene"]).agg(
        [
            pl.col("expression").mean().alias("avg_exp"),
            (pl.col("expression") > threshold).mean().mul(100).alias("pct_exp"),
        ]
    )

    dtplt = (
        ggplot(stats_frame, aes(x="gene", y=group_by))
        + geom_point(aes(size="pct_exp", color="avg_exp"))
        + scale_color_gradient(low=color_low, high=color_high)
    )

    dtplt = (
        ggplot(stats_frame, aes(x="gene", y=group_by))
        + geom_point(aes(size="pct_exp", color="avg_exp"))
        + scale_color_gradient(low=color_low, high=color_high)
    ) + _THEME_DOTPLOT

    if interactive:
        dtplt += ggtb(size_zoomin=-1)
    return dtplt
