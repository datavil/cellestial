# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read_h5ad("data/pbmc3k_pped.h5ad")
# data_spatial = sc.read_h5ad("data/V1_Human_Lymph_Node_pped.h5ad")
# data_hne = sq.datasets.visium_hne_adata()
data2 = sc.datasets.pbmc3k_processed()

# %%
for

# %%
# %%time
a = cl.build_frame(data,axis=0,variable_keys=data.var_names[:10])
print(f"Estimated size: {a.estimated_size('mb'):.2f} MB")
print(f"Shape: {a.shape}")

# %%
a = cl.build_frame(data,axis=1)

# %%
a.height*a.width

# %%
a.estimated_size("mb")
