# %%
import cellestial as cl
import scanpy as sc

from lets_plot import *

data = cl.datasets.pbmc3k(cache_directory="data")

umap = cl.umap(data, key="leiden", axis_type="arrow", size=1.5,legend_ondata=True,ondata_size=9,halo_width=0.5)

# %%
umap + ggtb(size_zoomin=0)
