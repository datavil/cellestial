# %%
from __future__ import annotations
from cellestial.frames import build_frame, anndata_variables_frame
import cellestial as cl
from collections.abc import Sequence


import polars as pl
from anndata import AnnData, read_h5ad

from lets_plot import LetsPlot
LetsPlot.setup_html()

# %%
data = read_h5ad("../data/example.h5ad")

# %%
build_frame(data, axis=0)

# %%
for key in data.var.columns:
    print(data.var[key].dtype)

# %%
anndata_variables_frame(data)

# %%
data.var.columns

# %%
col = data.var["feature_length"]
col

# %%
col.astype("int32")

# %%
build_frame(data, axis=1)

# %%
cl.umap(data,axis_type="arrow", key="cell_type", legend_ondata=True, ondata_size=6)

# %%
None in data.var_names

# %%
frame = build_frame(data, axis=0, include_dimensions=True)
frame.head()

# %%
cl.umap(data,key="ENSG00000146839", axis_type="arrow",arrow_length=0.1)

# %%
data.X

# %%
data.X[:, data.var_names.get_loc("ENSG00000146839")]

# %%
X = data.X.toarray()

# %%
X[:, data.var_names.get_loc("ENSG00000146839")]
