# %%
from __future__ import annotations
from cellestial.frames import build_frame, anndata_variables_frame

from collections.abc import Sequence


import polars as pl
from anndata import AnnData, read_h5ad

# %%
data = read_h5ad("../data/example.h5ad")

# %%
build_frame(data, axis=0)
# Out:
# shape: (9_705, 34)
# ┌─────────────┬─────┬─────────────┬────────────┬───┬────────┬────────────┬────────────┬────────────┐
# │ barcode     ┆ Age ┆ ClassAnn    ┆ Souporcell ┆ … ┆ tissue ┆ self_repor ┆ developmen ┆ observatio │
# │ ---         ┆ --- ┆ ---         ┆ ---        ┆   ┆ ---    ┆ ted_ethnic ┆ t_stage    ┆ n_joinid   │
# │ str         ┆ f64 ┆ cat         ┆ cat        ┆   ┆ cat    ┆ ity        ┆ ---        ┆ ---        │
# │             ┆     ┆             ┆            ┆   ┆        ┆ ---        ┆ cat        ┆ str        │
# │             ┆     ┆             ┆            ┆   ┆        ┆ cat        ┆            ┆            │
# ╞═════════════╪═════╪═════════════╪════════════╪═══╪════════╪════════════╪════════════╪════════════╡
# │ 10X239_4_AB ┆ 7.6 ┆ ChP         ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ 24jI(Qh?OH │
# │ _1:GAAACCTT ┆     ┆ Epithelial  ┆            ┆   ┆        ┆            ┆ stage 21   ┆            │
# │ CCATCTCG…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ 10X239_3_AB ┆ 7.6 ┆ ChP         ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ xQ#5onm}Iv │
# │ _1:GGAATCTT ┆     ┆ Epithelial  ┆            ┆   ┆        ┆            ┆ stage 21   ┆            │
# │ CCATTTGT…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ 10X238_2_AB ┆ 9.9 ┆ ChP         ┆ unassigned ┆ … ┆ meninx ┆ unknown    ┆ 9th week   ┆ ;~~`2P0zI* │
# │ _1:AGCATCAT ┆     ┆ Epithelial  ┆ -0         ┆   ┆        ┆            ┆ post-ferti ┆            │
# │ CTCCGTGT…   ┆     ┆             ┆            ┆   ┆        ┆            ┆ lization   ┆            │
# │             ┆     ┆             ┆            ┆   ┆        ┆            ┆ st…        ┆            │
# │ 10X239_4_AB ┆ 7.6 ┆ ChP         ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ bmh5;(QI7~ │
# │ _1:GCATGATT ┆     ┆ Epithelial  ┆            ┆   ┆        ┆            ┆ stage 21   ┆            │
# │ CTTGGGCG…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ 10X239_2_AB ┆ 8.4 ┆ ChP         ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ b-z~}?m7B# │
# │ _1:CTGGTCTC ┆     ┆ Epithelial  ┆            ┆   ┆        ┆            ┆ stage 23   ┆            │
# │ ACTTCAAG…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ …           ┆ …   ┆ …           ┆ …          ┆ … ┆ …      ┆ …          ┆ …          ┆ …          │
# │ 10X238_2_AB ┆ 9.9 ┆ Progenitor  ┆ unassigned ┆ … ┆ meninx ┆ unknown    ┆ 9th week   ┆ h@iWI`jC8g │
# │ _1:CCTCTAGG ┆     ┆             ┆ -0         ┆   ┆        ┆            ┆ post-ferti ┆            │
# │ TAACGCGA…   ┆     ┆             ┆            ┆   ┆        ┆            ┆ lization   ┆            │
# │             ┆     ┆             ┆            ┆   ┆        ┆            ┆ st…        ┆            │
# │ 10X234_2_AB ┆ 9.0 ┆ Progenitor  ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ 9th week   ┆ y3>$TWh}eF │
# │ _2:TCCGATCG ┆     ┆             ┆            ┆   ┆        ┆            ┆ post-ferti ┆            │
# │ TAGATCCT…   ┆     ┆             ┆            ┆   ┆        ┆            ┆ lization   ┆            │
# │             ┆     ┆             ┆            ┆   ┆        ┆            ┆ st…        ┆            │
# │ 10X297_4_AB ┆ 7.5 ┆ Progenitor  ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ A_%0HpKCBy │
# │ _1:AAGGTAAG ┆     ┆             ┆            ┆   ┆        ┆            ┆ stage 20   ┆            │
# │ TTACCCAA…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ 10X234_3_AB ┆ 9.0 ┆ Progenitor  ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ 9th week   ┆ PjGe7q<I8W │
# │ _1:ACTTTCAA ┆     ┆             ┆            ┆   ┆        ┆            ┆ post-ferti ┆            │
# │ GTGTTGAA…   ┆     ┆             ┆            ┆   ┆        ┆            ┆ lization   ┆            │
# │             ┆     ┆             ┆            ┆   ┆        ┆            ┆ st…        ┆            │
# │ 10X239_1_AB ┆ 8.4 ┆ Progenitor  ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ 3BMbhDBX9o │
# │ _1:TCCTCCCG ┆     ┆             ┆            ┆   ┆        ┆            ┆ stage 23   ┆            │
# │ TAATGCGG…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# └─────────────┴─────┴─────────────┴────────────┴───┴────────┴────────────┴────────────┴────────────┘

# %%
for key in data.var.columns:
    print(data.var[key].dtype)
# Out:
# category
# int64
# category
# int64
# category
# bool
# category
# category
# category
# category
# category

# %%
anndata_variables_frame(data)
# Out:
# shape: (33_159, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ variable  ┆ Chromosom ┆ End       ┆ Gene      ┆ … ┆ feature_r ┆ feature_b ┆ feature_l ┆ feature_ │
# │ ---       ┆ e         ┆ ---       ┆ ---       ┆   ┆ eference  ┆ iotype    ┆ ength     ┆ type     │
# │ str       ┆ ---       ┆ i64       ┆ cat       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ cat       ┆           ┆           ┆   ┆ cat       ┆ cat       ┆ i32       ┆ cat      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ENSG00000 ┆ 8         ┆ 80127670  ┆ AC009686. ┆ … ┆ NCBITaxon ┆ gene      ┆ 364       ┆ lncRNA   │
# │ 254205    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 4         ┆ 151291453 ┆ PRSS48    ┆ … ┆ NCBITaxon ┆ gene      ┆ 984       ┆ protein_ │
# │ 189099    ┆           ┆           ┆           ┆   ┆ :9606     ┆           ┆           ┆ coding   │
# │ ENSG00000 ┆ 7         ┆ 150076655 ┆ AC092666. ┆ … ┆ NCBITaxon ┆ gene      ┆ 726       ┆ lncRNA   │
# │ 241449    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 5         ┆ 9422481   ┆ AC091906. ┆ … ┆ NCBITaxon ┆ gene      ┆ 391       ┆ lncRNA   │
# │ 248537    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 16        ┆ 13204907  ┆ AC009134. ┆ … ┆ NCBITaxon ┆ gene      ┆ 443       ┆ lncRNA   │
# │ 262116    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ ENSG00000 ┆ 1         ┆ 46819413  ┆ CYP4B1    ┆ … ┆ NCBITaxon ┆ gene      ┆ 1289      ┆ protein_ │
# │ 142973    ┆           ┆           ┆           ┆   ┆ :9606     ┆           ┆           ┆ coding   │
# │ ENSG00000 ┆ 5         ┆ 179515579 ┆ AC136628. ┆ … ┆ NCBITaxon ┆ gene      ┆ 535       ┆ lncRNA   │
# │ 253652    ┆           ┆           ┆ 4         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 1         ┆ 211853703 ┆ AL445488. ┆ … ┆ NCBITaxon ┆ gene      ┆ 545       ┆ lncRNA   │
# │ 229258    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 15        ┆ 87579866  ┆ LINC00052 ┆ … ┆ NCBITaxon ┆ gene      ┆ 1966      ┆ lncRNA   │
# │ 259527    ┆           ┆           ┆           ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 7         ┆ 100797797 ┆ ZAN       ┆ … ┆ NCBITaxon ┆ gene      ┆ 8593      ┆ protein_ │
# │ 146839    ┆           ┆           ┆           ┆   ┆ :9606     ┆           ┆           ┆ coding   │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
data.var.columns
# Out:
# Index(['Chromosome', 'End', 'Gene', 'Start', 'Strand', 'feature_is_filtered',
#        'feature_name', 'feature_reference', 'feature_biotype',
#        'feature_length', 'feature_type'],
#       dtype='object')

# %%
col = data.var["feature_length"]
col
# Out:
# Accession
# ENSG00000254205     364
# ENSG00000189099     984
# ENSG00000241449     726
# ENSG00000248537     391
# ENSG00000262116     443
#                    ...
# ENSG00000142973    1289
# ENSG00000253652     535
# ENSG00000229258     545
# ENSG00000259527    1966
# ENSG00000146839    8593
# Name: feature_length, Length: 33159, dtype: int32

# %%
col.astype("int32")
# Out:
# Accession
# ENSG00000254205     364
# ENSG00000189099     984
# ENSG00000241449     726
# ENSG00000248537     391
# ENSG00000262116     443
#                    ...
# ENSG00000142973    1289
# ENSG00000253652     535
# ENSG00000229258     545
# ENSG00000259527    1966
# ENSG00000146839    8593
# Name: feature_length, Length: 33159, dtype: int32

# %%
build_frame(data, axis=1)
# Out:
# shape: (33_159, 12)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ variable  ┆ Chromosom ┆ End       ┆ Gene      ┆ … ┆ feature_r ┆ feature_b ┆ feature_l ┆ feature_ │
# │ ---       ┆ e         ┆ ---       ┆ ---       ┆   ┆ eference  ┆ iotype    ┆ ength     ┆ type     │
# │ str       ┆ ---       ┆ i64       ┆ cat       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ cat       ┆           ┆           ┆   ┆ cat       ┆ cat       ┆ i32       ┆ cat      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ ENSG00000 ┆ 8         ┆ 80127670  ┆ AC009686. ┆ … ┆ NCBITaxon ┆ gene      ┆ 364       ┆ lncRNA   │
# │ 254205    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 4         ┆ 151291453 ┆ PRSS48    ┆ … ┆ NCBITaxon ┆ gene      ┆ 984       ┆ protein_ │
# │ 189099    ┆           ┆           ┆           ┆   ┆ :9606     ┆           ┆           ┆ coding   │
# │ ENSG00000 ┆ 7         ┆ 150076655 ┆ AC092666. ┆ … ┆ NCBITaxon ┆ gene      ┆ 726       ┆ lncRNA   │
# │ 241449    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 5         ┆ 9422481   ┆ AC091906. ┆ … ┆ NCBITaxon ┆ gene      ┆ 391       ┆ lncRNA   │
# │ 248537    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 16        ┆ 13204907  ┆ AC009134. ┆ … ┆ NCBITaxon ┆ gene      ┆ 443       ┆ lncRNA   │
# │ 262116    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ ENSG00000 ┆ 1         ┆ 46819413  ┆ CYP4B1    ┆ … ┆ NCBITaxon ┆ gene      ┆ 1289      ┆ protein_ │
# │ 142973    ┆           ┆           ┆           ┆   ┆ :9606     ┆           ┆           ┆ coding   │
# │ ENSG00000 ┆ 5         ┆ 179515579 ┆ AC136628. ┆ … ┆ NCBITaxon ┆ gene      ┆ 535       ┆ lncRNA   │
# │ 253652    ┆           ┆           ┆ 4         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 1         ┆ 211853703 ┆ AL445488. ┆ … ┆ NCBITaxon ┆ gene      ┆ 545       ┆ lncRNA   │
# │ 229258    ┆           ┆           ┆ 1         ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 15        ┆ 87579866  ┆ LINC00052 ┆ … ┆ NCBITaxon ┆ gene      ┆ 1966      ┆ lncRNA   │
# │ 259527    ┆           ┆           ┆           ┆   ┆ :9606     ┆           ┆           ┆          │
# │ ENSG00000 ┆ 7         ┆ 100797797 ┆ ZAN       ┆ … ┆ NCBITaxon ┆ gene      ┆ 8593      ┆ protein_ │
# │ 146839    ┆           ┆           ┆           ┆   ┆ :9606     ┆           ┆           ┆ coding   │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘
