# %%
import cellestial as cl
import scanpy as sc


from lets_plot import *

import polars as pl

LetsPlot.setup_html()


data = sc.read("data/pbmc3k_pped.h5ad")

# %%
from cellestial.frames import _construct_cell_frame

# %%
data.obs.head()

# %%
_construct_cell_frame(
    data=data,
    keys=[],
    dimensions="umap",
    xy=(1, 2),
    use_key=None,
    barcode_name="barcode",
    var_name="Gene",
    to_add=["sample", "log1p_total_counts"],
)

# %%
data.var_names

# %%
_construct_cell_frame(
    data=data,
    keys=["leiden", "PCDH11Y", "MTCP1"],
    dimensions="umap",
    xy=(1, 2),
    use_key=None,
    barcode_name="CellID",
    var_name="Gene",
    to_add=["sample", "log1p_total_counts"],
)

# %%
data.var
