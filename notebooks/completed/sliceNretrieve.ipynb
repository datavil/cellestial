# %%
import scanpy as sc

import cellestial as cl

data = sc.read("data/pbmc3k_pped.h5ad")
from lets_plot import *

LetsPlot.setup_html()

# %%
data.obs.columns.to_list()

# %%
grid = cl.umaps(data, keys=data.obs.columns.to_list(), ncol=3)
grid

# %%
cl.slice(grid, index=[1,2,3])

# %%
plot= cl.umap(data, key="leiden", add_tooltips=["total_counts_mt","log1p_total_counts_ribo"])
plot

# %%
cl.retrieve(plot)

# %%
cl.retrieve(grid, index=0)

# %%
cl.retrieve(grid,index=150)
