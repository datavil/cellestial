# %%
from lets_plot import *
import cellestial as cl
LetsPlot.setup_html()
import anndata as ad

data = ad.read_h5ad("e9022f30-de8a-474e-8f39-81d877c6eac2.h5ad")
# Out:
#             <div id="3JtkJp"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("3JtkJp").appendChild(div);
#                     };
#                     var e = document.getElementById("3JtkJp");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
data.obs
# Out:
#                                  Age        ClassAnn    Souporcell  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx  7.6  ChP Epithelial     singlet-0
# 10X239_3_AB_1:GGAATCTTCCATTTGTx  7.6  ChP Epithelial     singlet-0
# 10X238_2_AB_1:AGCATCATCTCCGTGTx  9.9  ChP Epithelial  unassigned-0
# 10X239_4_AB_1:GCATGATTCTTGGGCGx  7.6  ChP Epithelial     singlet-0
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx  8.4  ChP Epithelial     singlet-0
# ...                              ...             ...           ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx  9.9      Progenitor  unassigned-0
# 10X234_2_AB_2:TCCGATCGTAGATCCTx  9.0      Progenitor     singlet-0
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx  7.5      Progenitor     singlet-0
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx  9.0      Progenitor     singlet-0
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx  8.4      Progenitor     singlet-0
#
#                                                      Subclass  Superclass  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx  ChP Differentiated epithelia  Epithelial
# 10X239_3_AB_1:GGAATCTTCCATTTGTx  ChP Differentiated epithelia  Epithelial
# 10X238_2_AB_1:AGCATCATCTCCGTGTx  ChP Differentiated epithelia  Epithelial
# 10X239_4_AB_1:GCATGATTCTTGGGCGx  ChP Differentiated epithelia  Epithelial
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx  ChP Differentiated epithelia  Epithelial
# ...                                                       ...         ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx       Midbrain hem progenitor      Neural
# 10X234_2_AB_2:TCCGATCGTAGATCCTx       Midbrain hem progenitor      Neural
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx       Midbrain hem progenitor      Neural
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx       Midbrain hem progenitor      Neural
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx       Midbrain hem progenitor      Neural
#
#                                 disease_ontology_term_id  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx             PATO:0000461
# 10X239_3_AB_1:GGAATCTTCCATTTGTx             PATO:0000461
# 10X238_2_AB_1:AGCATCATCTCCGTGTx             PATO:0000461
# 10X239_4_AB_1:GCATGATTCTTGGGCGx             PATO:0000461
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx             PATO:0000461
# ...                                                  ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx             PATO:0000461
# 10X234_2_AB_2:TCCGATCGTAGATCCTx             PATO:0000461
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx             PATO:0000461
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx             PATO:0000461
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx             PATO:0000461
#
#                                 self_reported_ethnicity_ontology_term_id  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx                                  unknown
# 10X239_3_AB_1:GGAATCTTCCATTTGTx                                  unknown
# 10X238_2_AB_1:AGCATCATCTCCGTGTx                                  unknown
# 10X239_4_AB_1:GCATGATTCTTGGGCGx                                  unknown
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx                                  unknown
# ...                                                                  ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx                                  unknown
# 10X234_2_AB_2:TCCGATCGTAGATCCTx                                  unknown
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx                                  unknown
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx                                  unknown
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx                                  unknown
#
#                                 assay_ontology_term_id  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx            EFO:0009922
# 10X239_3_AB_1:GGAATCTTCCATTTGTx            EFO:0009922
# 10X238_2_AB_1:AGCATCATCTCCGTGTx            EFO:0009922
# 10X239_4_AB_1:GCATGATTCTTGGGCGx            EFO:0009922
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx            EFO:0009922
# ...                                                ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx            EFO:0009922
# 10X234_2_AB_2:TCCGATCGTAGATCCTx            EFO:0009922
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx            EFO:0009922
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx            EFO:0009922
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx            EFO:0009922
#
#                                 development_stage_ontology_term_id donor_id  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx                     HsapDv:0000028  BRC2227
# 10X239_3_AB_1:GGAATCTTCCATTTGTx                     HsapDv:0000028  BRC2227
# 10X238_2_AB_1:AGCATCATCTCCGTGTx                     HsapDv:0000046  BRC2225
# 10X239_4_AB_1:GCATGATTCTTGGGCGx                     HsapDv:0000028  BRC2227
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx                     HsapDv:0000030  BRC2226
# ...                                                            ...      ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx                     HsapDv:0000046  BRC2225
# 10X234_2_AB_2:TCCGATCGTAGATCCTx                     HsapDv:0000046  BRC2222
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx                     HsapDv:0000027   XDD399
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx                     HsapDv:0000046  BRC2222
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx                     HsapDv:0000030  BRC2226
#
#                                  ... sex_ontology_term_id is_primary_data  \
# CellID                           ...
# 10X239_4_AB_1:GAAACCTTCCATCTCGx  ...         PATO:0000384           False
# 10X239_3_AB_1:GGAATCTTCCATTTGTx  ...         PATO:0000384           False
# 10X238_2_AB_1:AGCATCATCTCCGTGTx  ...         PATO:0000383           False
# 10X239_4_AB_1:GCATGATTCTTGGGCGx  ...         PATO:0000384           False
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx  ...         PATO:0000384           False
# ...                              ...                  ...             ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx  ...         PATO:0000383           False
# 10X234_2_AB_2:TCCGATCGTAGATCCTx  ...         PATO:0000383           False
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx  ...         PATO:0000383           False
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx  ...         PATO:0000383           False
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx  ...         PATO:0000384           False
#
#                                                       cell_type      assay  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx  choroid plexus epithelial cell  10x 3' v3
# 10X239_3_AB_1:GGAATCTTCCATTTGTx  choroid plexus epithelial cell  10x 3' v3
# 10X238_2_AB_1:AGCATCATCTCCGTGTx  choroid plexus epithelial cell  10x 3' v3
# 10X239_4_AB_1:GCATGATTCTTGGGCGx  choroid plexus epithelial cell  10x 3' v3
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx  choroid plexus epithelial cell  10x 3' v3
# ...                                                         ...        ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx          neural progenitor cell  10x 3' v3
# 10X234_2_AB_2:TCCGATCGTAGATCCTx          neural progenitor cell  10x 3' v3
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx          neural progenitor cell  10x 3' v3
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx          neural progenitor cell  10x 3' v3
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx          neural progenitor cell  10x 3' v3
#
#                                  disease     sex  tissue  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx   normal    male  meninx
# 10X239_3_AB_1:GGAATCTTCCATTTGTx   normal    male  meninx
# 10X238_2_AB_1:AGCATCATCTCCGTGTx   normal  female  meninx
# 10X239_4_AB_1:GCATGATTCTTGGGCGx   normal    male  meninx
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx   normal    male  meninx
# ...                                  ...     ...     ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx   normal  female  meninx
# 10X234_2_AB_2:TCCGATCGTAGATCCTx   normal  female  meninx
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx   normal  female  meninx
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx   normal  female  meninx
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx   normal    male  meninx
#
#                                 self_reported_ethnicity  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx                 unknown
# 10X239_3_AB_1:GGAATCTTCCATTTGTx                 unknown
# 10X238_2_AB_1:AGCATCATCTCCGTGTx                 unknown
# 10X239_4_AB_1:GCATGATTCTTGGGCGx                 unknown
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx                 unknown
# ...                                                 ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx                 unknown
# 10X234_2_AB_2:TCCGATCGTAGATCCTx                 unknown
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx                 unknown
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx                 unknown
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx                 unknown
#
#                                                  development_stage  \
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx                  Carnegie stage 21
# 10X239_3_AB_1:GGAATCTTCCATTTGTx                  Carnegie stage 21
# 10X238_2_AB_1:AGCATCATCTCCGTGTx  9th week post-fertilization stage
# 10X239_4_AB_1:GCATGATTCTTGGGCGx                  Carnegie stage 21
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx                  Carnegie stage 23
# ...                                                            ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx  9th week post-fertilization stage
# 10X234_2_AB_2:TCCGATCGTAGATCCTx  9th week post-fertilization stage
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx                  Carnegie stage 20
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx  9th week post-fertilization stage
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx                  Carnegie stage 23
#
#                                 observation_joinid
# CellID
# 10X239_4_AB_1:GAAACCTTCCATCTCGx         24jI(Qh?OH
# 10X239_3_AB_1:GGAATCTTCCATTTGTx         xQ#5onm}Iv
# 10X238_2_AB_1:AGCATCATCTCCGTGTx         ;~~`2P0zI*
# 10X239_4_AB_1:GCATGATTCTTGGGCGx         bmh5;(QI7~
# 10X239_2_AB_1:CTGGTCTCACTTCAAGx         b-z~}?m7B#
# ...                                            ...
# 10X238_2_AB_1:CCTCTAGGTAACGCGAx         h@iWI`jC8g
# 10X234_2_AB_2:TCCGATCGTAGATCCTx         y3>$TWh}eF
# 10X297_4_AB_1:AAGGTAAGTTACCCAAx         A_%0HpKCBy
# 10X234_3_AB_1:ACTTTCAAGTGTTGAAx         PjGe7q<I8W
# 10X239_1_AB_1:TCCTCCCGTAATGCGGx         3BMbhDBX9o
#
# [9705 rows x 33 columns]

# %%
u = cl.tsne(data, key="cell_type",size=0.8)+ggsize(600,400)+scale_color_hue()
u
# Out:
#    <div id="h4Hd6h"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("h4Hd6h");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "cell_type":["choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial  ...

# %%
u = cl.umap(
    data, 
    key="cell_type",
    size=0.8,q
    axis_type="arrow",
    arrow_length=0.1,
    arrow_size=0.5,
    arrow_angle=50,
)+ggsize(600,400)+scale_color_hue()
u
# Out:
#    <div id="B7toDm"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("B7toDm");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "cell_type":["choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial cell","choroid plexus epithelial  ...

# %%
cl.frames.anndata_observations_frame(data)
# Out:
# shape: (9_705, 34)
# ┌─────────────┬─────┬─────────────┬────────────┬───┬────────┬────────────┬────────────┬────────────┐
# │ barcode     ┆ Age ┆ ClassAnn    ┆ Souporcell ┆ … ┆ tissue ┆ self_repor ┆ developmen ┆ observatio │
# │ ---         ┆ --- ┆ ---         ┆ ---        ┆   ┆ ---    ┆ ted_ethnic ┆ t_stage    ┆ n_joinid   │
# │ str         ┆ f64 ┆ cat         ┆ cat        ┆   ┆ cat    ┆ ity        ┆ ---        ┆ ---        │
# │             ┆     ┆             ┆            ┆   ┆        ┆ ---        ┆ cat        ┆ str        │
# │             ┆     ┆             ┆            ┆   ┆        ┆ cat        ┆            ┆            │
# ╞═════════════╪═════╪═════════════╪════════════╪═══╪════════╪════════════╪════════════╪════════════╡
# │ 10X239_4_AB ┆ 7.6 ┆ ChP         ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ 24jI(Qh?OH │
# │ _1:GAAACCTT ┆     ┆ Epithelial  ┆            ┆   ┆        ┆            ┆ stage 21   ┆            │
# │ CCATCTCG…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ 10X239_3_AB ┆ 7.6 ┆ ChP         ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ xQ#5onm}Iv │
# │ _1:GGAATCTT ┆     ┆ Epithelial  ┆            ┆   ┆        ┆            ┆ stage 21   ┆            │
# │ CCATTTGT…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ 10X238_2_AB ┆ 9.9 ┆ ChP         ┆ unassigned ┆ … ┆ meninx ┆ unknown    ┆ 9th week   ┆ ;~~`2P0zI* │
# │ _1:AGCATCAT ┆     ┆ Epithelial  ┆ -0         ┆   ┆        ┆            ┆ post-ferti ┆            │
# │ CTCCGTGT…   ┆     ┆             ┆            ┆   ┆        ┆            ┆ lization   ┆            │
# │             ┆     ┆             ┆            ┆   ┆        ┆            ┆ st…        ┆            │
# │ 10X239_4_AB ┆ 7.6 ┆ ChP         ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ bmh5;(QI7~ │
# │ _1:GCATGATT ┆     ┆ Epithelial  ┆            ┆   ┆        ┆            ┆ stage 21   ┆            │
# │ CTTGGGCG…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ 10X239_2_AB ┆ 8.4 ┆ ChP         ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ b-z~}?m7B# │
# │ _1:CTGGTCTC ┆     ┆ Epithelial  ┆            ┆   ┆        ┆            ┆ stage 23   ┆            │
# │ ACTTCAAG…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ …           ┆ …   ┆ …           ┆ …          ┆ … ┆ …      ┆ …          ┆ …          ┆ …          │
# │ 10X238_2_AB ┆ 9.9 ┆ Progenitor  ┆ unassigned ┆ … ┆ meninx ┆ unknown    ┆ 9th week   ┆ h@iWI`jC8g │
# │ _1:CCTCTAGG ┆     ┆             ┆ -0         ┆   ┆        ┆            ┆ post-ferti ┆            │
# │ TAACGCGA…   ┆     ┆             ┆            ┆   ┆        ┆            ┆ lization   ┆            │
# │             ┆     ┆             ┆            ┆   ┆        ┆            ┆ st…        ┆            │
# │ 10X234_2_AB ┆ 9.0 ┆ Progenitor  ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ 9th week   ┆ y3>$TWh}eF │
# │ _2:TCCGATCG ┆     ┆             ┆            ┆   ┆        ┆            ┆ post-ferti ┆            │
# │ TAGATCCT…   ┆     ┆             ┆            ┆   ┆        ┆            ┆ lization   ┆            │
# │             ┆     ┆             ┆            ┆   ┆        ┆            ┆ st…        ┆            │
# │ 10X297_4_AB ┆ 7.5 ┆ Progenitor  ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ A_%0HpKCBy │
# │ _1:AAGGTAAG ┆     ┆             ┆            ┆   ┆        ┆            ┆ stage 20   ┆            │
# │ TTACCCAA…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# │ 10X234_3_AB ┆ 9.0 ┆ Progenitor  ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ 9th week   ┆ PjGe7q<I8W │
# │ _1:ACTTTCAA ┆     ┆             ┆            ┆   ┆        ┆            ┆ post-ferti ┆            │
# │ GTGTTGAA…   ┆     ┆             ┆            ┆   ┆        ┆            ┆ lization   ┆            │
# │             ┆     ┆             ┆            ┆   ┆        ┆            ┆ st…        ┆            │
# │ 10X239_1_AB ┆ 8.4 ┆ Progenitor  ┆ singlet-0  ┆ … ┆ meninx ┆ unknown    ┆ Carnegie   ┆ 3BMbhDBX9o │
# │ _1:TCCTCCCG ┆     ┆             ┆            ┆   ┆        ┆            ┆ stage 23   ┆            │
# │ TAATGCGG…   ┆     ┆             ┆            ┆   ┆        ┆            ┆            ┆            │
# └─────────────┴─────┴─────────────┴────────────┴───┴────────┴────────────┴────────────┴────────────┘
