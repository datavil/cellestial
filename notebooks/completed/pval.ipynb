# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read("data/pbmc3k_pped.h5ad")

# %%
data

# %%
br = cl.bar(
    data,
    mapping=aes(x="cell_type_lvl1", y="CD3D", fill="cell_type_lvl1"),
    stat="summary",
)
br + cl.layers.bracket(y_position=1.2, prefix="p", prefix_style="<", label="pvalue")

# %%
cl.boxplot(
    data,
    key="",
    fill="cell_type_lvl1",
)
