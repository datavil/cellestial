# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

data = cl.datasets.pbmc3k()

# %%
import cellestial as cl
import scanpy as sc

from lets_plot import *

data = cl.datasets.pbmc3k(cache_directory="data")

histogram = (
    cl.histogram(data, "n_genes_by_counts", binwidth=1000,fill="cell_type_lvl1")
    + ggsize(800, 400)
)

histogram

# %%
f = cl.retrieve(histogram)
f

# %%
ggplot(f) + geom_histogram(aes(x="n_genes_by_counts"),fill=,bins=10)
