# %%
import scanpy as sc
import squidpy as sq
from lets_plot import *

import cellestial as cl

data = sc.read_h5ad("data/pbmc3k_pped.h5ad")

# %%
adata = sc.datasets.pbmc68k_reduced()

# %%
cl.rank_genes_groups(adata, line=True)

# %%
adata

# %%
adata.obs["bulk_labels"].unique().tolist()[0::3]

# %%
cl.rank_genes_groups(
    adata,
    groups=["CD14+ Monocyte", "CD4+/CD25 T Reg", "CD4+/CD45RO+ Memory", "CD34+"],
    ncol=2,
    rank_color=True,
)

# %%
cl.rank_genes_groups(adata, groupby="cell_type_lvl1", line=True) + theme_classic()

# %%
cl.rank_genes_groups(
            adata,
            groups=["CD14+ Monocyte", "CD4+/CD25 T Reg", "CD4+/CD45RO+ Memory", "CD34+"],
            ncol=2,
            rank_color=True,
        )
