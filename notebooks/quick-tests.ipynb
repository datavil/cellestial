# %%
import polars as pl
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read("data/endocrinogenesis_day15_pped.h5ad")
data.obs.head()

# %%
data.obsm

# %%
dim = (
    cl.umap(
        data,
        key="clusters_coarse",
        axis_type="arrow",
        size=4,
        alpha=0.4,
        legend_ondata=True,
        ondata_color="black",
    )
    + ggsize(600, 400)
    + scale_color_viridis(option="plasma")
)
dim

# %%
frame = cl.retrieve(dim)
mapping = cl.get_mapping(dim)
x = mapping.get("x")
y = mapping.get("y")
mapping.pop("color")

# %%
prefix = "velocity_".upper()
end_prefix = "END"
x_velocity = f"{prefix}{x.replace('X_', '')}"
y_velocity = f"{prefix}{y.replace('X_', '')}"
x_end = f"{end_prefix}_{x.replace('X_', '')}"
y_end = f"{end_prefix}_{y.replace('X_', '')}"
frame = frame.with_columns(
    pl.col(x).add(pl.col(x_velocity)).alias(x_end),
    pl.col(y).add(pl.col(y_velocity)).alias(y_end),
)

# %%
frame.select(
    "X_UMAP1", "X_UMAP2", "VELOCITY_UMAP1", "VELOCITY_UMAP2", "END_UMAP1", "END_UMAP2"
).head()

# %%
mapping.update({"xend": x_end, "yend": y_end})

# %%
mapping

# %%
import scvelo as scv

# %%
scv.pl.velocity_embedding_stream(data)

# %%
X_emb = data.obsm["X_umap"]
V_emb = data.obsm["velocity_umap"]

# %%
from scvelo.plotting.velocity_embedding_grid import compute_velocity_on_grid

X_grid, V_grid = compute_velocity_on_grid(
    X_emb=X_emb,  # your UMAP coords, shape (n_cells, 2)
    V_emb=V_emb,  # your velocity coords, shape (n_cells, 2)
    adjust_for_stream=True,  # reshapes output into the meshgrid format needed for streams
    density=1,
    smooth=0.5,
    min_mass=1,
)

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
stream = ax.streamplot(
    X_grid[0],
    X_grid[1],
    V_grid[0],
    V_grid[1],
    density=2,
    maxlength=4,
    integration_direction="both",
)
paths = stream.lines.get_paths()  # extract line segment coordinates
plt.close(fig)  # throw away the plot

# %%
import polars as pl

# extract path segments
records = [
    {"x": float(x), "y": float(y), "group": i}
    for i, path in enumerate(paths)
    for x, y in path.vertices
    if len(path.vertices) > 3  # skip arrowheads
]

df_streams = pl.DataFrame(records)

# %%
df_streams

# %%
df_arrows = (
    (
        df_streams.group_by("group")
        .agg(
            pl.col("x"),
            pl.col("y"),
        )
        .with_columns(mid=pl.col("x").list.len() // 2)
    )
    .with_columns(
        x=pl.col("x").list.get(pl.col("mid")),
        y=pl.col("y").list.get(pl.col("mid")),
        xend=pl.col("x").list.get(pl.col("mid").add(1)),
        yend=pl.col("y").list.get(pl.col("mid").add(1)),
    )
    .drop("mid")
    .sort("group")
)
df_arrows

# %%
(
    dim
    + geom_path(aes("x", "y", group="group"), data=df_streams, color="black", alpha=0.7, size=1)
    + geom_segment(
        aes("x", "y", xend="xend", yend="yend"),
        data=df_arrows,
        arrow=arrow(type="closed", length=6),
        color="black",
        size=1,
    )
) + scale_color_viridis(option="viridis")

# %%
scv.pl.velocity_embedding_stream(data)

# %%
import numpy as np
from scipy.integrate import solve_ivp

def make_vector_field(X, Y, U, V):
    """Create interpolated vector field from grid."""
    from scipy.interpolate import RegularGridInterpolator

    interp_u = RegularGridInterpolator((Y, X), U)
    interp_v = RegularGridInterpolator((Y, X), V)

    def field(t, xy):
        x, y = xy
        u = interp_u((y, x))
        v = interp_v((y, x))
        return [u, v]

    return field


def compute_streamlines(X, Y, U, V, seeds, t_span=(0, 5), max_step=0.1):
    field = make_vector_field(X, Y, U, V)

    paths = []
    for seed in seeds:
        sol = solve_ivp(
            field,
            t_span,
            seed,
            max_step=max_step,
            dense_output=False,
        )
        paths.append(sol.y.T)  # shape (N, 2)

    return paths

# %%
(
    dim
    + geom_path(aes("x", "y", group="group"), data=df_streams, color="black", alpha=0.7, size=1)
    + geom_segment(
        aes("x", "y", xend="xend", yend="yend"),
        data=df_arrows,
        arrow=arrow(type="closed", length=6),
        color="black",
        size=1,
    )
) + scale_color_viridis(option="viridis")

# %%
from matplotlib.figure import Figure

fig = Figure()
ax = fig.add_subplot(111)

stream = ax.streamplot(
    X_grid[0],
    X_grid[1],
    V_grid[0],
    V_grid[1],
    density=density,
    maxlength=max_length,
    integration_direction=integration_direction,
)

paths = stream.lines.get_paths()
