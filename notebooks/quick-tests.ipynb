# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

cl.setup_html(width_mode="fixed", height_mode="fixed")

# %%
data = cl.datasets.pbmc3k()
data = data[::40]

# %%
sc.tl.rank_genes_groups(data, "cell_type_lvl1")

# %%
keys = cl.marker_genes(data, n_genes=20)

# %%
data.var

# %%
c = cl.annotated_heatmap(
    data,
    keys,
    group_by="cell_type_lvl1",
    row_annotations=["cell_type_lvl1", "sample"],
    column_annotations=["highly_variable", "hb", "ribo", "mt", "highly_variable_intersection"],
    legend=True,
    layers=[scale_fill_viridis()],
    layers_all=[
        cl.borders(panel_color="rgba(0,0,0,0)", plot_size=2, legend_size=2),
        # theme(legend_title=element_blank()),
    ],
) + ggsize(500, 800)
c

# %%
f8 = cl.get_figure(c, 8)
f8

# %%
title_panel = ggplot() + geom_text(x=0, y=0, label="expression", size=8, angle=0) + theme_void()
f8 += theme_minimal2()

gggrid([f8, title_panel + cl.borders()], ncol=2, widths=[10, 1])

# %%
from lets_plot import *

LetsPlot.setup_html()

# %%
frame = {"x": list(range(1, 11)), "y": [i**2 for i in range(1, 11)]}

(
    ggplot(frame, aes("x", "y"))
    + geom_point()
    + ylab("y-title")
    + xlab("x-title")
    + theme(axis_title_x=element_text(angle=90, vjust=0.5))
)

# %%
c.to_png("axis_title_issue.png")

# %%
frame = {"x": list(range(1, 11)), "y": [i**2 for i in range(1, 11)]}

(
    ggplot(frame, aes("x", "y"))
    + geom_point()
    + ylab("y-title")
    + xlab("x-title")
    + theme(axis_title_y=element_text(angle=0, vjust=0.5))
)
