# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read_h5ad("data/pbmc3k_pped.h5ad")
# data_spatial = sc.read_h5ad("data/V1_Human_Lymph_Node_pped.h5ad")
# data_hne = sq.datasets.visium_hne_adata()
data2 = sc.datasets.pbmc3k_processed()

# %%
sc.tl.rank_genes_groups(data, "cell_type_lvl1")

# %%
cl.umaps(data, keys=cl.marker_genes(data, n_genes=3), ncol=3, share_labels=True, align=True)

# %%
cl.marker_genes_dict(
    data,
)

# %%
cl.violin(
    data,
    key=cl.marker_genes(data, n_genes=3),
    show_points=False,
    fill="cell_type_lvl1",
    scale="width",
    threhold=1,
) + facet_grid(y="cell_type_lvl1")

# %%
cl.violin(
    data,
    key=cl.marker_genes(data, n_genes=3),
    show_points=False,
    fill="cell_type_lvl1",
    scale="width",
)
