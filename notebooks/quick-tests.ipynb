# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read("data/pbmc3k_pped.h5ad")
velocity_data = sc.read("data/endocrinogenesis_day15_pped.h5ad")

# %%
markers = ["C1QA", "PSAP", "CD79A", "CD79B", "CST3", "LYZ"]

# %%
cl.heatmap(
    data,
    group_by="leiden",
    keys=markers,
    dendrogram=True,
    scale=1,
)

# %% [markdown]
# dendrograms should not increase in size for every iteration
# why are they increasing in size exponentially.
#
# also dendrograms for the rows should be on the right
#
# it is

# %%
cl.dotplot(
    data,
    group_by="cell_type_lvl1",
    keys=markers,
    dendrogram=True,
    color_high="#FF0000",
)

# %%
cl.retrieve(cl.dotplot(
    data,
    group_by="leiden",
    keys=markers,
    dendrogram=True,
    color_high="#FF0000",
) + coord_flip())

# %%
cl.retrieve(cl.heatmap(
    data,
    group_by="leiden",
    keys=markers,
    dendrogram=True,
    color_high="#FF0000",
) + coord_flip())

# %%
cl.dotplot(
    data,
    group_by="cell_type_lvl1",
    keys=markers,
    dendrogram=True,
    color_high="#FF0000",
)

# %%
cl.heatmap(
    data,
    group_by="cell_type_lvl1",
    keys=markers,
    dendrogram=True,
    scale_axis=1,
)

# %%
htmp = cl.heatmap(
    data,
    group_by="leiden",
    keys=markers,
    aggregate=False,
    geom="raster",
    dendrogram=True,
    dendrogram_size="0.7",
    group_bars_titles=True,
)

htmp

# %%
htmp = (
    cl.heatmap(
        data,
        group_by="cell_type_lvl1",
        keys=markers,
        geom="raster",
        aggregate=False,
        group_lines_size=0.5,
        group_lines_color="white",
        dendrogram=True,
        dendrogram_size="0.7",
        group_bars_titles=True,
        group_bars=True,
    )
    + scale_fill_viridis()
)
htmp

# %%
htmp = cl.heatmap(
    data,
    group_by="cell_type_lvl1",
    keys=markers,
    geom="raster",
    dendrogram=True,
    aggregate=False,
)
htmp

# %%
htmp = (
    cl.heatmap(
        data,
        group_by="cell_type_lvl1",
        keys=markers,
        aggregate=False,
        geom="tile",
        group_bars=True,
        dendrogram=True,
        tooltips=["value"],
        color="",
    )
    + scale_fill_viridis()
)
htmp

# %%
# Filter the data to include only cells with a valid label
sc.pl.heatmap(
    data[data.obs["cell_type_lvl1"].notna()],
    var_names=markers,
    groupby="cell_type_lvl1",
    dendrogram=True,
)
