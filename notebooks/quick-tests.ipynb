# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read("data/pbmc3k_pped.h5ad")
velocity_data = sc.read("data/endocrinogenesis_day15_pped.h5ad")

# %%
markers = ["C1QA", "PSAP", "CD79A", "CD79B", "CST3", "LYZ"]

# %%
markers = [
    # T Cells (Pan)
    "CD3E",
    "CD3D",
    "CD3G",
    # CD4+ T Cells (Helper)
    "CD4",
    # CD8+ T Cells (Cytotoxic)
    "CD8A",
    "CD8B",
    # Regulatory T Cells (Tregs)
    "FOXP3",
    "IL2RA",  # CD25
    # Naive T Cells
    "CCR7",
    "SELL",  # CD62L
    # Effector / Effector Memory T Cells
    "GZMB",
    "GZMK",
    "GZMA",
    "PRF1",
    "IFNG",
    # Tissue-Resident Memory T Cells (Trm)
    "ITGAE",  # CD103
    "ITGA1",  # CD49a
    "CXCR6",
    # Exhausted T Cells
    "PDCD1",  # PD-1
    "HAVCR2",  # TIM-3
    "LAG3",
    "TIGIT",
    "CTLA4",
    "ENTPD1",  # CD39
    "TOX",
    # Gamma-Delta T Cells
    "TRDC",
    "TRGC1",
    "TRGC2",
    # NKT Cells
    "KLRB1",  # CD161
    # Natural Killer (NK) Cells
    "NCAM1",  # CD56
    "FCGR3A",  # CD16
    "KLRD1",  # CD94
    "KLRK1",  # NKG2D
    "KLRC1",  # NKG2A
    "NCR1",  # NKp46
    "NCR2",  # NKp44
    "NCR3",  # NKp30
    "GNLY",
    "NKG7",
    "XCL1",
    "XCL2",
    # B Cells (Pan)
    "CD19",
    "MS4A1",  # CD20
    "CD79A",
    "CD79B",
    # Naive B Cells
    "IGHD",
    "IGHM",
    # Memory B Cells
    "CD27",
    # Germinal Center B Cells
    "BCL6",
    "AICDA",  # AID
    # Plasma Cells / Plasmablasts
    "IGHG1",
    "IGHG2",
    "IGHG3",
    "IGHG4",
    "IGHA1",
    "IGHA2",
    "IGHE",
    "SDC1",  # CD138
    "PRDM1",  # BLIMP1
    "XBP1",
    "MZB1",
    # Classical Monocytes
    "CD14",
    # Non-Classical Monocytes
    "FCGR3A",  # CD16 (also NK)
    "CX3CR1",
    # Pan Monocyte / Myeloid
    "LYZ",
    "S100A8",
    "S100A9",
    "CSF1R",
    # Conventional Dendritic Cells type 1 (cDC1)
    "CLEC9A",
    "XCR1",
    "CADM1",
    "THBD",  # CD141/BDCA-3
    # Conventional Dendritic Cells type 2 (cDC2)
    "CLEC10A",  # CD301
    "FCER1A",
    "CD1C",
    # Plasmacytoid Dendritic Cells (pDC)
    "CLEC4C",  # BDCA-2
    "IL3RA",  # CD123
    "TCF4",  # E2-2
    "LILRA4",
    "SELL",  # CD62L
    # Macrophages (Pan)
    "CD68",
    "ITGAM",  # CD11b
    "MRC1",  # CD206 / Mannose receptor
    "FCGR1A",  # CD64
    "ADGRE1",  # F4/80 (mouse)
    # M1 Macrophages
    "TNF",
    "IL1B",
    "IL6",
    "CXCL9",
    "CXCL10",
    # M2 Macrophages
    "CD163",
    "MRC1",
    "CCL18",
    "IL10",
    # Tissue-Specific Macrophages
    "TIMD4",  # Kupffer cells / resident macrophages
    "FOLR2",  # Tissue-resident macrophages
    "C1QA",
    "C1QB",
    "C1QC",  # Kupffer / interstitial macrophages
    # Mast Cells
    "TPSAB1",
    "TPSB2",  # Tryptase
    "CPA3",
    "KIT",  # CD117
    "HDC",  # Histidine decarboxylase
    "MS4A2",  # FcεRI beta
    # Basophils
    "GATA2",
    "IL4",
    # Eosinophils
    "SIGLEC8",
    "CCR3",
    "EPX",
    "RNASE3",
    # Neutrophils
    "FCGR3B",  # CD16b
    "CXCR1",
    "CXCR2",
    "S100A12",
    "ELANE",
    "MPO",
    "CEACAM8",  # CD66b
    # Innate Lymphoid Cells (ILC)
    "IL7R",  # CD127 — pan ILC
    "KLRB1",  # CD161 — pan ILC
    # ILC1
    "TBX21",  # T-bet
    "IFNG",
    # ILC2
    "GATA3",
    "IL13",
    "IL5",
    "PTGDR2",
    # ILC3 / NK22
    "RORC",  # RORγt
    "IL22",
    "IL17A",
    "NCR2",  # NKp44
    # Hematopoietic Stem / Progenitor Cells (HSPC)
    "CD34",
    "CD38",
    "KIT",
    "FLT3",
    # Erythroid Precursors
    "HBA1",
    "HBA2",
    "HBB",
    "GYPA",  # CD235a
    # Platelets / Megakaryocytes
    "PPBP",
    "PF4",
    "GP1BA",  # CD42b
    "ITGA2B",  # CD41
    # Proliferating / Cycling Cells (universal)
    "MKI67",
    "TOP2A",
    "PCNA",
]

unique_markers = list(set(markers))
markers = [u for u in unique_markers if u in data.var_names][:20]

# %%
cl.heatmap(
    data,
    group_by="cell_type_lvl1",
    keys=markers,
    aggregate=False,
    color_low=cl.LIGHT_GRAY,
    color_mid="#FFFFFF",
    color_high="#FF0000",
    dendrogram=False,
    group_bars_labels = True,
)

# %%
cl.dotplot(
    data,
    group_by="cell_type_lvl1",
    keys=markers,
    color_low=cl.LIGHT_GRAY,
    color_high="#FF0000",
    dendrogram=True,
    size_scale=2,
    rectangle=False,
)

# %%
dt = (
    cl.dotplot(
        data,
        shape=21,
        mapping=aes(fill="avg_exp"),
        use_fill=True,
        group_by="leiden",
        keys=markers,
        color_high="#FF0000",
        dendrogram=False,
        stroke=0,
    )
    + theme()
)
dt

# %%
rt = cl.violin(data, group_by="leiden", key=markers, use_fill=True)
frame = cl.retrieve(rt)

# %%
frame["variable"].unique()

# %%
data.n_obs

# %%
sc.pl.violin(data, keys=markers, groupby="leiden")

# %%
a = cl.violins(
    data,
    keys=markers,
    fill="leiden",
    group_by="leiden",
    show_points=False,
    tooltips="none",
    ncol=2,
    threshold=0.1,
    trim=False,
)
a

# %%
frame = cl.retrieve(a)

# %%
cl.retrieve(cl.umap(data))["n_genes_by_counts"].max()
