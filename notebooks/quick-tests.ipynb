# %%
import polars as pl
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read("data/pbmc3k_pped.h5ad")
velocity_data = sc.read("data/endocrinogenesis_day15_pped.h5ad")

# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

data = sc.read_h5ad("data/pbmc3k_pped.h5ad")

ridge = (
    cl.ridge(
        data,
        "B2M",
        threshold=0.2,
        group_by="cell_type_lvl1",
        scale=2,
        trim=False,
        alpha=0.5,
    )
    + scale_fill_hue()
    + scale_y_log10()
    + ggtitle("B2M")
)
ridge

# %%
r = (
    cl.ridge(data, key="B2M", threshold=0.2, scale=2, geom_fill="gray")
    + scale_fill_hue()
    + scale_y_log10()
)
r

# %%
r = (
    cl.ridge(data, key="B2M", group_by="cell_type_lvl1", threshold=0.2, scale=2, fill="gray")
    + scale_fill_hue()
)
r

# %%
ggplot(cl.retrieve(r)) + geom_area_ridges(
    aes(
        x="B2M",
        y=None,
    )
)

# %%
import numpy as np
import scanpy as sc

import cellestial as cl

data = sc.read_h5ad("data/pbmc3k_pped.h5ad")
# get the top 8 genes with the highest mean expression
gene_means = np.asarray(data.X.mean(axis=0)).flatten()
top8_genes = data.var_names[np.argsort(gene_means)[::-1][:8]].tolist()

cl.ridges(
    data,
    keys=top8_genes,
    group_by="cell_type_lvl1",
    alpha=0.7,
    scale=2,
    ncol=2,
    color="#3f3f3f",
    guides="collect",
)
