# %%
from __future__ import annotations

from anndata import read_h5ad
from lets_plot import *

LetsPlot.setup_html()
import cellestial as cl
# Out:
#         <div id="zDX0LG"></div>
#         <script type="text/javascript" data-lets-plot-script="library">
#             if(!window.letsPlotCallQueue) {
#                 window.letsPlotCallQueue = [];
#             };
#             window.letsPlotCall = function(f) {
#                 window.letsPlotCallQueue.push(f);
#             };
#             (function() {
#                 var script = document.createElement("script");
#                 script.type = "text/javascript";
#                 script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js";
#                 script.onload = function() {
#                     window.letsPlotCall = function(f) {f();};
#                     window.letsPlotCallQueue.forEach(function(f) {f();});
#                     window.letsPlotCallQueue = [];
#
#                 };
#                 script.onerror = function(event) {
#                     window.letsPlotCall = function(f) {};    // noop
# ...

# %%
data = read_h5ad("data/pbmc3k_pped.h5ad")

# %%
cl.build_frame(data,axis=0,include_dimensions=250)
# Out:
# shape: (16_680, 75)
# ┌────────────┬────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ barcode    ┆ sample ┆ n_genes_by ┆ log1p_n_g ┆ … ┆ X_TSNE1   ┆ X_TSNE2   ┆ X_UMAP1   ┆ X_UMAP2   │
# │ ---        ┆ ---    ┆ _counts    ┆ enes_by_c ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ cat    ┆ ---        ┆ ounts     ┆   ┆ f32       ┆ f32       ┆ f32       ┆ f32       │
# │            ┆        ┆ i32        ┆ ---       ┆   ┆           ┆           ┆           ┆           │
# │            ┆        ┆            ┆ f64       ┆   ┆           ┆           ┆           ┆           │
# ╞════════════╪════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ AAACCCAAGG ┆ s1d1   ┆ 2103       ┆ 7.651596  ┆ … ┆ -8.471021 ┆ 0.673473  ┆ 10.702534 ┆ 1.695078  │
# │ ATGGCT-1   ┆        ┆            ┆           ┆   ┆           ┆           ┆           ┆           │
# ...

# %%
cl.build_frame(data,axis=1,include_dimensions=20)
# Out:
# shape: (2_000, 37)
# ┌────────────┬───────┬───────┬───────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ variable   ┆ mt    ┆ ribo  ┆ hb    ┆ … ┆ PCS17     ┆ PCS18     ┆ PCS19     ┆ PCS20     │
# │ ---        ┆ ---   ┆ ---   ┆ ---   ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ bool  ┆ bool  ┆ bool  ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪═══════╪═══════╪═══════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ AL390719.2 ┆ false ┆ false ┆ false ┆ … ┆ 0.000592  ┆ 0.000521  ┆ -0.000477 ┆ -0.000384 │
# │ C1QTNF12   ┆ false ┆ false ┆ false ┆ … ┆ -0.006791 ┆ -0.001876 ┆ 0.001695  ┆ 0.005245  │
# │ AL162741.1 ┆ false ┆ false ┆ false ┆ … ┆ -0.001654 ┆ 0.003159  ┆ -0.000388 ┆ 0.001114  │
# │ LINC01786  ┆ false ┆ false ┆ false ┆ … ┆ 0.000801  ┆ -0.000601 ┆ 0.001574  ┆ -0.000991 │
# │ AL391244.2 ┆ false ┆ false ┆ false ┆ … ┆ -0.001865 ┆ -0.003884 ┆ -0.003769 ┆ 0.003923  │
# ...

# %%
for x in data.obsm:
    print(data.obsm[x].shape)
# Out:
# (16680, 50)
# (16680, 2)
# (16680, 2)

# %%
type((1,2))
# Out:
# tuple

# %%
a = (1,2)
max(a)
# Out:
# 2
