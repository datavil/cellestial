# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
# data = sc.read_h5ad("data/pbmc3k_pped.h5ad")
# data_spatial = sc.read_h5ad("data/V1_Human_Lymph_Node_pped.h5ad")
# data_hne = sq.datasets.visium_hne_adata()

data = sc.datasets.pbmc3k_processed()

# %%
cl.pca(data, "louvain", size=3)

# %%
cl.pca(data, "louvain", size=3) + cl.cluster_outlines(data.obs["louvain"].unique(), color="black")
