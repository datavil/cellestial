# %%
import polars as pl
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read("data/pbmc3k_pped.h5ad")
velocity_data = sc.read("data/endocrinogenesis_day15_pped.h5ad")

# %%
import scanpy as sc

sc.pp.highly_variable_genes(data,n_top_genes=50)
hvg = data.var_names[data.var["highly_variable"]].tolist()

# %%
hvg

# %%
cl.heatmap(
    data,
    group_by="leiden",
)

# %%
cl.heatmap(
    data,
    group_by="cell_type_lvl1",
    keys=hvg,
)
