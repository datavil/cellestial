# %%
import polars as pl
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read("data/pbmc3k_pped.h5ad")
data.obs.head()

# %%
cl.tsne(data, key="CD14", color_high=cl.TEAL)

# %%
cl.tsne(data, key="cell_type_lvl1", size=None)

# %%
(
    cl.umap(
        data,
        mapping=aes(size="CD14", fill="cell_type_lvl1"),
        shape=21,
        variable_keys="CD14",
        color="black",
        stroke=0.3,
    )
    + scale_fill_viridis()
)
