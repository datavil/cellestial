# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read("data/pbmc3k_pped.h5ad")
velocity_data = sc.read("data/endocrinogenesis_day15_pped.h5ad")

# %%
sc.pp.log1p(data)

# %%
import cellestial as cl
import scanpy as sc

from lets_plot import *

data = sc.read_h5ad("data/pbmc3k_pped.h5ad")

umap = cl.umap(data, key="cell_type_lvl1", axis_type="arrow")
umap + cl.ondata_legend()

# %%
umap + cl.ondata_legend(size=10, family="mono", fontface="italic")

# %%
sc.tl.rank_genes_groups(data,groupby="cell_type_lvl1")

# %%
from cellestial.single.special.volcano import _build_volcano_frame

# %%
_build_volcano_frame(data,group="Lymphocytes",group_by="cell_type_lvl1")

# %%
cl.volcano(data,group="Lymphocytes",tooltips="none")+scale_y_log2()

# %%
cl.volcanos(data,groups=data.obs["cell_type_lvl1"].dropna().unique().tolist(),ncol=2)

# %%
data.obs["cell_type_lvl1"].dropna().unique().tolist()

# %%
f = cl.retrieve(cl.volcano(data,group="Lymphocytes"))
f

# %%
ggplot(f)+ geom_bar(aes(x="significance"))
