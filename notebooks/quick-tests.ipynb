# %%
from __future__ import annotations

from anndata import read_h5ad
from lets_plot import *
import cellestial as cl

from sys import getsizeof

# %%
data = read_h5ad("data/pbmc3k_pped.h5ad")

# %%
cl.dimensional(data, key="cell_type_lvl1") + facet_wrap("cell_type_lvl1")

# %%
aes(aes(x="x", y="y").as_dict() | aes(y="y1", x="0", color="coloraad").as_dict())

# %%
cl.xyplot(data, "X_UMAP1", "X_UMAP2", mapping=aes(color="leiden"))

# %%
cl.xyplots(
    data,
    "n_genes_by_counts",
    [
        "total_counts_mt",
        "log1p_total_counts_mt",
        "pct_counts_in_top_500_genes",
        "total_counts_ribo",
    ],
    mapping=aes(color="leiden"),
    ncol=2,
)

# %%
from lets_plot import *

LetsPlot.setup_html()

import cellestial as cl
import scanpy as sc

data = sc.read_h5ad("data/pbmc3k_pped.h5ad")

chart = (
    cl.plot(data, axis=0)
    + geom_violin(aes(fill="cell_type_lvl1"), scale="width")
    + geom_boxplot(width=0.2, outlier_size=0)
    + scale_fill_viridis()
)

# %%
chart
