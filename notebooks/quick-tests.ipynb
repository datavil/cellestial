# %%
import squidpy as sq
from lets_plot import *

import cellestial as cl

# %%
import squidpy as sq
from lets_plot import *

import cellestial as cl

data = sq.datasets.visium_hne_adata()

cl.spatial(data,"cluster",interactive=True)
