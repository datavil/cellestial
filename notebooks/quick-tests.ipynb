# %%
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = cl.datasets.pbmc3k()
data = data[::20]

# %%
keys = data.var_names[:100]

# %%
data.var

# %%
c = cl.annotated_heatmap(
    data,
    keys,
    group_by="cell_type_lvl1",
    row_annotations=["cell_type_lvl1", "sample"],
    column_annotations=["highly_variable"],
    legend=True,
    layers=scale_fill_viridis()
) + theme(
            legend_position="bottom",
            legend_box="horizontal",
            legend_direction="horizontal",
            legend_title=element_text(size=1),
            legend_text=element_text(size=1),
            legend_key_size=0,
)
c

# %%
a = cl.get_figure(c,2)

# %%
type(a)

# %%
a

# %%
scale_color_brewer(palette="dada")

# %%
 Spectral, Accent, Dark2, Paired, Pastel1, Pastel2, Set1, Set2, Set3.
