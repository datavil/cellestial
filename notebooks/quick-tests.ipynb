# %%
from __future__ import annotations

from anndata import read_h5ad
from lets_plot import *

LetsPlot.setup_html()
import cellestial as cl

# %%
data = read_h5ad("data/pbmc3k_pped.h5ad")

# %%
frame = cl.build_frame(data,axis=0,include_dimensions=True)
frame.head()

# %%
(
    ggplot(frame)
    + geom_point(aes(x="X_UMAP1",y="X_UMAP2",color="sample"),tooltips=None)
)

# %%
(
    ggplot(frame)
    + geom_boxplot(aes(y="total_counts",color="sample"))
)

# %%
class Nucleotide:
    pass

class DNA(Nucleotide):
    pass


a = DNA()

# %%
isinstance(a,Nucleotide)

# %%
from lets_plot.plot.core import FeatureSpec, LayerSpec

# %%
from lets_plot import *

# %%
a = layer_tooltips()

# %%
isinstance(a, LayerSpec)

# %%
observations_name = "dsfsf"
key = None

tooltips = [observations_name]
tooltips.append(key)
tooltips
