# %%
import squidpy as sq
from lets_plot import *
import scanpy as sc
import cellestial as cl

# %%
data = sc.read_h5ad("data/pbmc3k_pped.h5ad")
data_spatial = sc.read_h5ad("data/V1_Human_Lymph_Node_pped.h5ad")
data_hne = sq.datasets.visium_hne_adata()

# %%
data_spatial

# %%
markers = {
    "B-cell": ["CD79A", "MS4A1"],
    "Dendritic": ["FCER1A", "CST3"],
    "Monocytes": ["FCGR3A"],
    "NK": ["GNLY", "NKG7"],
    "Other": ["IGLL1"],
    "T-cell": ["CD3D"],
}

# %%
htmp = (
    cl.heatmap(
        data,
        group_by="cell_type_lvl1",
        keys=markers,
        geom="raster",
        group_lines_size=0.5,
        group_lines_color="white",
        dendrogram=True,
        dendrogram_size=1,
        group_bars_labels=True,
        group_bars=True,
        key_labels_text_size=0.5
    )
    + scale_fill_viridis()
)
htmp

# %%
htmp = (
    cl.heatmap(
        data,
        group_by="cell_type_lvl1",
        keys=markers,
        geom="raster",
        group_lines_size=0.5,
        group_lines_color="white",
        dendrogram=True,
        dendrogram_size=1,
        group_bars_labels=True,
        group_bars=True,
    )
    + scale_fill_viridis()

)
htmp

# %%
mtrx = cl.matrixplot(
    data,
    group_by="leiden",
    keys=markers,
    group_lines_size=0.5,
    group_lines_color="white",
    dendrogram=True,
    dendrogram_size=1,
) + scale_fill_viridis(option="inferno", begin=0.1)
mtrx + ggtb() + cl.borders()

# %%
stck = cl.stacked_violin(
    data,
    group_by="leiden_res_0.50",
    keys=markers,
    dendrogram=True,
    dendrogram_size=1,
    key_labels_text_size=12
)
stck + cl.borders()

# %%
dtplt = cl.dotplot(
    data,
    group_by="leiden_res_0.50",
    keys=markers,
    dendrogram=True,
    dendrogram_size=1,
    key_labels_text_size=30
)
dtplt + cl.borders()

# %%
cl.dotplot(data,markers,group_by="cell_type_lvl1")+cl.borders()

# %%
cl.dotplot(data,markers,group_by="leiden")+cl.borders()

# %%
import scanpy as sc

sc.tl.rank_genes_groups(data, groupby="cell_type_lvl1")
cl.heatmap(data, rank_genes_groups=True,key_labels=True)

# %%
import scanpy as sc
adata = sc.datasets.pbmc68k_reduced()

# %%
import scanpy as sc
adata = sc.datasets.pbmc68k_reduced()

# %%
cl.heatmap(adata,rank_genes_groups=True,key_labels=True,size=10)  + scale_fill_viridis()
