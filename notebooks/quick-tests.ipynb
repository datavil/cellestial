# %%
import polars as pl
import scanpy as sc
from lets_plot import *

import cellestial as cl

# %%
data = sc.read("data/pbmc3k_pped.h5ad")
velocity_data = sc.read("data/endocrinogenesis_day15_pped.h5ad")

# %%
cl.violin(data, key="HLA-DRA", threshold=0.1)

# %%
cl.violin(
    data,
    key="HLA-DRA",
    threshold=0.1,
    group_by="cell_type_lvl1",
    fill="cell_type_lvl1",
    scale="width",
    size=1,
)

# %%
vln = cl.violin(
    data,
    key="HLA-DRA",
    threshold=0.1,
    mapping= aes(fill="cell_type_lvl1"),
    scale="width",

)
vln

# %%
frame = cl.retrieve(vln)
frame.head()

# %%
ggplot(frame) + geom_violin(mapping=aes(x="cell_type_lvl1", y="HLA-DRA",color="cell_type_lvl1"),color=None)

# %%
print(None or None)
