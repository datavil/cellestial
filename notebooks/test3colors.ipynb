# %%
import scanpy as sc

import cellestial as cl

data = sc.read("data/pbmc3k_pped.h5ad")
from lets_plot import *

LetsPlot.setup_html()

# %%
cl.umap(data, key="MT-ND5", size=0.9) + scale_color_gradient2(
    low=cl.BLUE, mid="white", high=cl.CHERRY
)

# %%
data.var

# %%
col = data[:, 'NEAT1'].X
mid = (col.max().item() + col.min().item()) / 2

# %%
data.layers

# %%
data[:, 'NEAT1'].X.flatten().mean()

# %%
data.var
