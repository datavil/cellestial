# %%
from lets_plot import *
import cellestial as cl

# %%
import scanpy as sc

data = sc.datasets.pbmc3k_processed()

# %%
import scanpy as sc
from lets_plot import layer_tooltips
from cellestial.util import _resolve_tooltips, _tooltip_fields

data = sc.read_h5ad("data/pbmc3k_pped.h5ad")

# %%
cl.umap(
    data,
    tooltips=layer_tooltips()
    .line("@Barcode")
    .line("@MT-ND2")
    .line("@CD14")
    .line("@cell_type_lvl1"),
)

# %%
tt = layer_tooltips().line("@Barcode").line("@MT-ND2").line("@CD14").line("@cell_type_lvl1")

# %%
tt.as_dict()

# %%
cl.util._tooltip_fields(tt)
