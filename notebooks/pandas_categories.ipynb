# %%
import cellestial as cl
import anndata


data = anndata.read_h5ad("data/pbmc3k_pped.h5ad")

# %%
cl.frames.build_frame(data,axis=0,variable_keys="MT-ND2")
# Out:
# shape: (16_680, 22)
# ┌─────────────┬────────┬─────────────┬─────────────┬───┬────────────┬─────────┬────────┬───────────┐
# │ barcode     ┆ sample ┆ n_genes_by_ ┆ log1p_n_gen ┆ … ┆ pct_counts ┆ n_genes ┆ leiden ┆ MT-ND2    │
# │ ---         ┆ ---    ┆ counts      ┆ es_by_count ┆   ┆ _hb        ┆ ---     ┆ ---    ┆ ---       │
# │ str         ┆ cat    ┆ ---         ┆ s           ┆   ┆ ---        ┆ i64     ┆ cat    ┆ f32       │
# │             ┆        ┆ i32         ┆ ---         ┆   ┆ f32        ┆         ┆        ┆           │
# │             ┆        ┆             ┆ f64         ┆   ┆            ┆         ┆        ┆           │
# ╞═════════════╪════════╪═════════════╪═════════════╪═══╪════════════╪═════════╪════════╪═══════════╡
# │ AAACCCAAGGA ┆ s1d1   ┆ 2103        ┆ 7.651596    ┆ … ┆ 0.196237   ┆ 2103    ┆ 0      ┆ 0.031961  │
# │ TGGCT-1     ┆        ┆             ┆             ┆   ┆            ┆         ┆        ┆           │
# ...

# %%
for i in []:
    print(type(i))

# %%
type(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 type(i)
#
# NameError: name 'i' is not defined
