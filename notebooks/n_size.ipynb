# %%
import numpy as np
from sys import getsizeof

# %%
np.zeros(1_000_000,dtype=np.float32)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], shape=(1000000,), dtype=float32)

# %%
getsizeof(np.zeros(1_000_000,dtype=np.float32))
# Out:
# 4000112
