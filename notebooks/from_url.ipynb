# %%
import cellestial as cl
import scanpy as sc

from lets_plot import *

# %%
data = cl.datasets.from_url(
    "https://datasets.cellxgene.cziscience.com/fc4eb6b6-16c8-4c1c-b478-58697cd11a32.h5ad"
)

# %%
data.uns["spatial"]["Bx003_combined"]["images"]["fullres"].shape

# %%
data.uns["spatial"]["Bx003_combined"]["images"]["hires"].shape

# %%
cl.spatial(
    data[data.obs["in_tissue"] == 1],
    library_id="Bx003_combined",
    key="cell_type",
    size=2,
    interactive=True,
) + theme(
    panel_background=element_blank(),
    plot_background=element_blank(),
    legend_background=element_blank(),
)

# %%
from anndata import AnnData
