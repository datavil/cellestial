# %%
import cellestial as cl
import scanpy as sc

# %%
data = cl.datasets.from_url("https://datasets.cellxgene.cziscience.com/fc4eb6b6-16c8-4c1c-b478-58697cd11a32.h5ad")

# %%
data.uns["spatial"]["Bx003_combined"]["images"]["fullres"].shape

# %%
data.uns["spatial"]["Bx003_combined"]["images"]["hires"].shape

# %%
cl.spatial(data,library_id="Bx003_combined",key="cell_type")

# %%
sc.pl.spatial(data, color="cell_type", size=1.5,library_id="Bx003_combined")

# %%
import squidpy as sq
sq.pl.spatial_scatter(data, color="cell_type", size=1.5,library_id="Bx003_combined")
